# %%
import os
import sys
import glob
import datetime as dt
import pandas as pd
import numpy as np
import blmfire as blm
from importlib import reload
from sklearn.feature_extraction.text import CountVectorizer

# %%
testfile_current = "./testdata/blmfiredata.txt"
testfile_prev = "./testdata/20170713_065905_blmfiredata.txt"

# %%
fieldmap = blm.FIELDMAP
fieldmap['lastupdatedatetime'] = 'firesadmin.dailyfirerecord.lastupdatedatetime'
fieldmap['discoverydatetime'] = 'firesadmin.fire.discoverydatetime'
fieldmap['guid'] = 'firesadmin.fire.irwinid'

# %%
def get_data(fn):
    data = blm.get_raw_fire_data(fn, tryremote=False)
    fieldnames = blm.sanitize_dataline(data[0], blanks=3, lower=True)
    rawdata = [blm.sanitize_dataline(
                item.strip(), blanks=2, lower=False) for item in data[1::2]]
    
    # the transformed data will be a list of dictionaries
    data = blm.get_firedata(fieldnames, rawdata)
    return fieldnames, data

# %%
fieldnames, data = get_data(testfile_current)

# %%
_, data_prev = get_data(testfile_prev)

# %%
def cleanup_df(dataframe):
    dataframe['discoverydatetime'] = pd.to_datetime(dataframe['discoverydatetime'], unit='ms')
    dataframe['lastupdatedatetime'] = pd.to_datetime(dataframe['lastupdatedatetime'], unit='ms')
    dataframe['containmentdatetime'] = pd.to_datetime(dataframe['containmentdatetime'], unit='ms')
    try:
        dataframe['controldatetime'] = pd.to_datetime(dataframe['controldatetime'], unit='ms')
    except KeyError:  # can be empty
        pass
    dataframe['acreage'] = pd.to_numeric(dataframe['acreage'])
    return dataframe

# %%
df_current = pd.DataFrame(data)[list(fieldmap.values())]
df_current.columns = [list(fieldmap.keys())]
df_prev = pd.DataFrame(data_prev)[list(fieldmap.values())]
df_prev.columns = [list(fieldmap.keys())]

# %%
df_current = cleanup_df(df_current)
df_prev = cleanup_df(df_prev)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/cwaigl/anaconda2/envs/snowflakes35/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'containmentdatetime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-66b05a9498d3> in <module>()
# ----> 1 df_current = cleanup_df(df_current)
#       2 df_prev = cleanup_df(df_prev)
#
# <ipython-input-8-a2a5741fa519> in cleanup_df(dataframe)
#       2     dataframe['discoverydatetime'] = pd.to_datetime(dataframe['discoverydatetime'], unit='ms')
#       3     dataframe['lastupdatedatetime'] = pd.to_datetime(dataframe['lastupdatedatetime'], unit='ms')
# ----> 4     dataframe['containmentdatetime'] = pd.to_datetime(dataframe['containmentdatetime'], unit='ms')
#       5     try:
#       6         dataframe['controldatetime'] = pd.to_datetime(dataframe['controldatetime'], unit='ms')
#
# /Users/cwaigl/anaconda2/envs/snowflakes35/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/cwaigl/anaconda2/envs/snowflakes35/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/cwaigl/anaconda2/envs/snowflakes35/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/cwaigl/anaconda2/envs/snowflakes35/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/cwaigl/anaconda2/envs/snowflakes35/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'containmentdatetime'

# %%
df_prev[~df_prev['designation'].isin(df_current['designation'])].to_csv()
# Out:
# ',cause,longitude,guid,structuresburned,acreage,maintext,designation,discoverydatetime,latitude,primaryfueltype,numberpeople,structuresthreatened,lastupdatedatetime\n36,Lightning,-153.4959444,8976669B-225E-490A-B614-1C4177A29BCB,0,19.6,Zone aircraft N309VS flew the fire area today. Fire personnel reported no change in size or fire behavior. Update in acreage due to more accurate mapping.,North Kusko,2017-06-16 17:25:11.529,63.6799445,Black Spruce,0,0,2017-06-20 12:48:00.529\n55,Lightning,-141.9646944,D5E3FDDD-7110-4B2E-BFDD-309649EA21F1,0,3.1,Landsat imagery confirmed initial coordinates and fire size.,Martin Creek,2017-07-02 17:15:08.544,68.0495556,Tundra,0,0,2017-07-08 11:51:00.544\n56,Lightning,-141.9171667,D078470D-8A60-480F-8647-45B43214A593,0,0.1,The fire was flown by zone aircraft N9011N. No fire activity was observed.,Coleen River,2017-07-02 17:18:46.544,68.0861667,Tundra,0,0,2017-07-09 18:56:00.544\n'

# %%
df_current[~df_current['designation'].isin(df_prev['designation'])]
# Out:
#         cause     longitude                                  guid  \
# 46  Lightning  -144.6955833  C6ED6EFA-EBCF-4B58-8AAA-260BEBBDA871
# 47  Lightning   -144.316667  607BB758-6C06-4E35-8A4A-9B5EFEF53D52
#
#    structuresburned  acreage  \
# 46                0      1.0
# 47                0      0.0
#
#                                              maintext        designation  \
# 46  The fire was discovered by zone aircraft N222M...            WL 543T
# 47  A small column of smoke was reported to the du...  George Lake Hills
#
#          discoverydatetime    latitude primaryfueltype numberpeople  \
# 46 2017-07-13 17:15:04.730  67.0030278    Black Spruce            0
# 47 2017-07-13 08:10:24.731       63.75         Unknown            0
#
#    structuresthreatened      lastupdatedatetime
# 46                    0 2017-07-13 19:52:00.730
# 47                    0 2017-07-14 04:03:45.731

# %%
today = dt.datetime.now()
df_current.loc[(today - df_current['lastupdatedatetime'] < dt.timedelta(days=2))]
# Out:
# Empty DataFrame
# Columns: [cause, longitude, guid, structuresburned, acreage, maintext, designation, discoverydatetime, latitude, primaryfueltype, numberpeople, structuresthreatened, lastupdatedatetime]
# Index: []

# %%
df_prev.set_index('guid')[['lastupdatedatetime', 'acreage']]
# Out:
#                                           lastupdatedatetime  acreage
# guid
# 231B0E11-EA79-4FFD-A44C-84130064B858 2017-07-09 09:17:00.513    178.2
# 8719131D-F468-481F-A61A-8DF15C13887B 2017-07-04 10:40:00.513      4.7
# 3CE4F630-EF46-49EF-9A2D-3186E3DCE0C7 2017-07-08 22:05:00.513     20.0
# E1963C4B-0888-4A60-B5B8-D8FFA8B8DF3A 2017-07-12 20:49:00.513    356.8
# B18CE0AB-470E-49A5-97B5-3B1790C668C9 2017-07-04 22:11:00.513    332.0
# 5F36D2F7-347D-4FBA-8C2C-0B21984A7607 2017-07-07 17:51:00.513     25.0
# 1E5D3F64-62ED-4149-AB71-53535BDD0504 2017-07-12 20:46:00.513  22227.3
# 8FC76EFB-5229-42B5-8ED8-D1F9B325106A 2017-07-12 17:43:00.513      4.0
# 21207F32-B0BD-42F8-A1FA-C4A7AC6EC464 2017-07-11 06:31:00.513    235.4
# 7391C476-78BC-4C8D-A100-61644BBF6828 2017-07-12 19:51:00.513  10188.8
# 55246098-9363-4C87-83DC-9365AAE42444 2017-07-10 06:34:00.513      1.0
# 3D216138-6824-46B8-9254-835C46E21EF1 2017-07-09 07:09:00.513     21.8
# 86A07501-8395-4D5D-B812-A18DA398F01D 2017-07-11 23:33:00.513  23673.6
# E62589A2-BEEB-4C62-B7E3-B5AB44788049 2017-07-09 07:05:00.513    514.0
# 0B2B8CCE-46B4-4A29-8D4E-4E05EBE30105 2017-07-11 19:31:00.513     25.0
# 1A9701F4-2CC0-4B80-8456-92F8BB4CD593 2017-07-07 04:00:05.513   1016.0
# F9D1A784-3DDF-438E-831C-C3772FF4D5EA 2017-07-08 22:28:00.513     30.0
# 1C166729-9871-415C-AB4E-D72CA0EAB2B1 2017-07-10 06:35:00.513   8344.9
# DF352EC9-385F-45EE-A1D6-028A5144C433 2017-07-09 18:48:00.513      1.0
# 9F95EFE7-6DB9-43C3-8984-9E2BEA50B6BE 2017-07-09 16:15:00.513     14.6
# F86DF691-23C6-40D2-BB4C-52E624145FAF 2017-07-07 23:11:00.513   2876.5
# C0BD59B1-6D5C-4552-9E7C-201571B6EFCB 2017-07-09 16:15:00.513    200.0
# C1446D0C-39BF-46C9-BD52-E709BD0B7902 2017-07-12 21:20:00.513  33100.3
#                                      2017-06-20 04:00:05.513      0.5
# 94939C6A-B76A-4926-859B-88FAB24F67FA 2017-06-20 04:00:05.529      1.5
# C65F6C92-E038-4C72-BB2E-990EE1B4532B 2017-06-16 22:12:00.529      0.4
# DC5D8B8C-8437-4C56-8822-187E33619168 2017-07-12 21:31:00.529  23383.9
# 2B4F6923-8854-45F4-86B3-501F635FE76F 2017-07-09 07:01:00.529   2583.5
# A5ED7846-822B-48D6-811C-6958088DE0CD 2017-06-08 23:52:00.529      5.2
# D3AAABF1-D21F-4768-A605-4698B313BEEB 2017-07-06 04:00:06.529  16514.0
# ...                                                      ...      ...
# B272457B-0306-41B4-903F-ABE3D6DC12F3 2017-06-15 10:11:00.529     51.6
# 91068E54-7C07-4C4F-AA8A-B44162E3903D 2017-07-06 04:00:05.529  12945.0
# 8976669B-225E-490A-B614-1C4177A29BCB 2017-06-20 12:48:00.529     19.6
# 89EDCE37-D59E-4073-BA8F-28348BBFA492 2017-07-12 21:33:00.529    338.6
# 4E655EFA-5A64-4442-93BC-20A0CDA12342 2017-07-12 17:49:32.529      2.8
# 0B8D7795-C042-4165-A540-C22C3FFEFA8B 2017-07-07 12:47:00.529     45.2
# CB846635-C8CB-4734-8DC9-2C787C6C58F6 2017-07-12 19:41:00.529  56227.4
# 14025835-30F7-4E28-B709-4B1A34BBC458 2017-07-04 10:35:00.529   1647.4
# CD900D9B-9773-49E1-A693-F8B11B5C378E 2017-07-03 10:16:00.529   2870.3
# 7E55427E-8529-44D4-B927-C1DCE2BE0B45 2017-07-06 04:00:05.529    127.0
# 142D0B21-2C27-4B8A-875A-BC2E0B63ECF5 2017-07-06 04:00:06.529  16823.9
# 1D8128D1-BB46-4052-A5FB-8CF15924AC7E 2017-07-07 06:30:00.529      0.2
# 3BCA8DE3-A9AE-4617-999D-6DC536FB9362 2017-07-09 18:49:00.529   2549.3
# 1BFBD1FA-A1C2-44AF-872F-F3F33B20D146 2017-07-10 21:52:00.529  11757.7
# 022B3833-8BAA-4CF8-AC50-CF235F065649 2017-07-11 06:36:00.529  15797.9
# 5D51BD09-96C4-4973-868C-9DB8D08EA242 2017-06-18 11:36:00.529     11.5
# A61F4906-8340-4905-AC58-E9F2007E95CC 2017-07-12 07:14:00.529    514.5
# 2C007BB1-9855-425F-A852-6C69C2DE4A9A 2017-07-06 04:00:05.529  13924.0
# DB9F9DD4-AA84-41A2-9DBD-321A58BF6D90 2017-07-11 11:04:00.529    491.6
# CBEEBD25-594D-43BD-B474-263954852A86 2017-06-29 04:00:05.544    832.0
# 42B24ADA-4F12-4E48-BA50-D52A1D8E7311 2017-07-09 16:07:00.544    200.0
# D5E3FDDD-7110-4B2E-BFDD-309649EA21F1 2017-07-08 11:51:00.544      3.1
# D078470D-8A60-480F-8647-45B43214A593 2017-07-09 18:56:00.544      0.1
# D9326B52-1219-470D-A745-D0B75A5271E8 2017-06-27 15:22:00.544    306.8
# C98E06E8-0F8C-45AF-949D-70CF6458E703 2017-07-06 04:00:06.544   2653.0
# 6BE59E0A-1E92-4FDE-8112-4E03D05C4B94 2017-07-12 19:54:00.544   3130.0
# B5454133-E82F-4255-81C4-AAE28C7E284C 2017-07-08 18:13:00.544     90.0
# A2974B0D-45D4-4B36-BB53-7FB91EC100F9 2017-06-30 20:49:00.544      0.2
# 4EEFEF37-FCD0-48B1-844C-31AA9507A756 2017-07-11 06:32:00.544    380.0
# BF193C80-A9FC-41DE-A790-0756CB58450C 2017-07-11 21:45:00.544   2228.8
#
# [64 rows x 2 columns]

# %%
df_joined = df_current.join(df_prev.set_index('guid')[['lastupdatedatetime', 'acreage', 'maintext']], on='guid', rsuffix='_prev')

# %%
df_joined['delta_acres'] = df_joined['acreage'] - df_joined['acreage_prev']

# %%
df_joined.iloc[[6, 9,12, 22, 23, 27, 47, 49, 51, 55]][['designation', 'latitude', 'longitude', 'delta_acres']].to_csv('testout')

# %%
df_current.sort_values('acreage', ascending=False, axis=0).head()
# Out:
#         cause     longitude                                  guid  \
# 39  Lightning  -141.3181389  CB846635-C8CB-4734-8DC9-2C787C6C58F6
# 23  Lightning  -141.0150278  C1446D0C-39BF-46C9-BD52-E709BD0B7902
# 49  Lightning  -142.0123333  022B3833-8BAA-4CF8-AC50-CF235F065649
# 12  Lightning  -141.3226944  86A07501-8395-4D5D-B812-A18DA398F01D
# 27  Lightning  -143.7333333  DC5D8B8C-8437-4C56-8822-187E33619168
#
#    structuresburned  acreage  \
# 39                0  62800.9
# 23                0  45521.7
# 49                0  27629.4
# 12                0  23673.6
# 27                0  23383.9
#
#                                              maintext           designation  \
# 39  The fire was flown by surveillance aircraft N2...  White Mountain Creek
# 23  At 1500 the fire was flown by zone surveillanc...        Campbell River
# 49  Zone aircraft N222ME flew the fire and reporte...            Lois Creek
# 12  Zone aircraft N222ME flew the fire and reporte...        Ammerman Creek
# 27  Zone surveillance aircraft N222ME flew the fir...         Boulder Creek
#
#          discoverydatetime    latitude primaryfueltype numberpeople  \
# 39 2017-07-03 14:09:32.724  67.4532778    Black Spruce            0
# 23 2017-06-26 17:14:24.711  67.2183056    Black Spruce           35
# 49 2017-07-02 17:28:36.733  68.2916667         Tussock            0
# 12 2017-06-23 17:05:48.701  68.4175833    Black Spruce            0
# 27 2017-07-02 15:12:31.714       67.45    Black Spruce           75
#
#    structuresthreatened      lastupdatedatetime
# 39                    0 2017-07-14 09:48:00.724
# 23                    0 2017-07-13 21:05:00.711
# 49                    0 2017-07-13 18:40:00.733
# 12                    0 2017-07-13 18:51:00.701
# 27                    0 2017-07-14 09:49:00.714

# %%
condition_recent = (today - df_current['lastupdatedatetime'] < dt.timedelta(days=2))

# %%
df_current[condition_recent]['maintext'].to_csv()
# Out:
# '2,Zone surveillance aircraft N309VS flew the fire and reported no visible smoke.\n3,"On 7/13, the fire received precipitation and no dominant smokes were visible from the highway; however, drift smoke was present in the area. An unmanned UAS flew the fire and captured infrared images indicating areas of heat. On 7/14, all resources will demobilize from the fire and the fire will remain in monitor status. Fire size decreased to 332 acres due to more accurate mapping."\n6,Zone surveillance aircraft N222ME flew the area of the fire but was unable to observe it due to heavy smoke.\n7,The fire was demobilized and placed into monitor status.\n9,Zone surveillance aircraft N222ME flew the fire and reported it with a 10 percent active perimeter. The fire behavior was described as smoldering in a spruce/hardwood/brush mix. Observations were taken under 40 percent cloud cover.\n11,"The fire was flown by zone aircraft N22ME. No smoke, growth or active perimeter was reported."\n12,"Zone aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering and creeping.  Personnel on board identified the largest amount activity on the southeast corner.  The fire remains west of Ammerman Creek and north of the Old Crow River."\n15,"Two recon flights were conducted over fire 231, neither found smoke. Personnel took approximately four tons of equipment and supplies off the fire by helicopter and ground. None of the connected suppression equipment was dismantled or taken off the fire."\n20,"Fire is contained and controlled, and will be placed into monitor status."\n21,At 1545 zone surveillance aircraft N222ME flew reconnaissance over the fire. No smokes and no active perimeter were observed.\n22,Increase in acreage matches latest perimeter.\n23,At 1500 the fire was flown by zone surveillance aircraft N222ME. The fire was 25 percent active and was spreading to the north. Observed fire behavior included backing and torching in black spruce with 10 foot flame lengths. Weather observed included wind out of the north at 10 mph with 10 percent cloud cover and no precipitation.  Fire is most active on the SW edge.  A 12 mile line of fire has burned 2.10 miles south of the Salmon Trout allotment.   Resources on scene of the allotment and cabin continued to monitor weather and fuel conditions in preparation for a burnout operation. Higher relative humidities kept fuels damp and no burn was attempted. The Midnight Sun IHC began to pretreat areas around the allotment with water.  Tommorow personnel will continue monitoring conditions. A helicopter reconnaissance flight has been scheduled for tomorrow (7/14).\n27,Zone surveillance aircraft N222ME flew the fire and reported it with a 30 percent active perimeter and spreading to the north. The fire was creeping and backing with isolated torching in black spruce. Observations were taken under 30 percent cloud cover with calm winds.   Personnel on the ground continued to improve upon the saw line around the allotment. An UAS (unmanned aircraft system) was launched and performed a recon over the fire.\n30,The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.\n36,The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.\n37,The fire was flown by surveillance aircraft N222ME. Fire 312 has consumed fire 303.\n39,The fire was flown by surveillance aircraft N222ME. The fire area was too smokey to make observations. New fire size result of update imaging.\n43,Personnel began backhauling structure protection equipment.\n46,"The fire was discovered by zone aircraft N222ME during a detection flight. Personnel on board reported a 1 acre fire, 100 percent active, burning on flat terrain in black spruce. The fire plotted in a Limited suppression area and no values at risk were identified. The Upper Yukon Zone will continue to monitor this fire with aerial resources."\n47,A small column of smoke was reported to the duty  ...

# %%
count_vect = CountVectorizer()
firetextcounts = count_vect.fit_transform(df_current[condition_recent]['maintext'])

# %%
count_vect.vocabulary_.get('no smoke')

# %%
print(df_current[condition_recent]['maintext'].to_csv())
# Out:
# 2,Zone surveillance aircraft N309VS flew the fire and reported no visible smoke.
# 3,"On 7/13, the fire received precipitation and no dominant smokes were visible from the highway; however, drift smoke was present in the area. An unmanned UAS flew the fire and captured infrared images indicating areas of heat. On 7/14, all resources will demobilize from the fire and the fire will remain in monitor status. Fire size decreased to 332 acres due to more accurate mapping."
# 6,Zone surveillance aircraft N222ME flew the area of the fire but was unable to observe it due to heavy smoke.
# 7,The fire was demobilized and placed into monitor status.
# 9,Zone surveillance aircraft N222ME flew the fire and reported it with a 10 percent active perimeter. The fire behavior was described as smoldering in a spruce/hardwood/brush mix. Observations were taken under 40 percent cloud cover.
# 11,"The fire was flown by zone aircraft N22ME. No smoke, growth or active perimeter was reported."
# 12,"Zone aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering and creeping.  Personnel on board identified the largest amount activity on the southeast corner.  The fire remains west of Ammerman Creek and north of the Old Crow River."
# 15,"Two recon flights were conducted over fire 231, neither found smoke. Personnel took approximately four tons of equipment and supplies off the fire by helicopter and ground. None of the connected suppression equipment was dismantled or taken off the fire."
# 20,"Fire is contained and controlled, and will be placed into monitor status."
# 21,At 1545 zone surveillance aircraft N222ME flew reconnaissance over the fire. No smokes and no active perimeter were observed.
# 22,Increase in acreage matches latest perimeter.
# 23,At 1500 the fire was flown by zone surveillance aircraft N222ME. The fire was 25 percent active and was spreading to the north. Observed fire behavior included backing and torching in black spruce with 10 foot flame lengths. Weather observed included wind out of the north at 10 mph with 10 percent cloud cover and no precipitation.  Fire is most active on the SW edge.  A 12 mile line of fire has burned 2.10 miles south of the Salmon Trout allotment.   Resources on scene of the allotment and cabin continued to monitor weather and fuel conditions in preparation for a burnout operation. Higher relative humidities kept fuels damp and no burn was attempted. The Midnight Sun IHC began to pretreat areas around the allotment with water.  Tommorow personnel will continue monitoring conditions. A helicopter reconnaissance flight has been scheduled for tomorrow (7/14).
# 27,Zone surveillance aircraft N222ME flew the fire and reported it with a 30 percent active perimeter and spreading to the north. The fire was creeping and backing with isolated torching in black spruce. Observations were taken under 30 percent cloud cover with calm winds.   Personnel on the ground continued to improve upon the saw line around the allotment. An UAS (unmanned aircraft system) was launched and performed a recon over the fire.
# 30,The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.
# 36,The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.
# 37,The fire was flown by surveillance aircraft N222ME. Fire 312 has consumed fire 303.
# 39,The fire was flown by surveillance aircraft N222ME. The fire area was too smokey to make observations. New fire size result of update imaging.
# 43,Personnel began backhauling structure protection equipment.
# 46,"The fire was discovered by zone aircraft N222ME during a detection flight. Personnel on board reported a 1 acre fire, 100 percent active, burning on flat terrain in black spruce. The fire plotted in a Limited suppression area and no values at risk were identified. The Upper Yukon Zone will continue to monitor this fire with aerial resources."
# 47,A small column of smoke was reported to the duty officer around 22:30 on 7/12 by a resident on Sand Lake.  Helitack responded after the fog and mist lifted on 7/13.  The reporter could no longer see any smoke once helitack was launched.  Helicopter 873HL thoroughly scanned the area and did not find any blackened ground or smoke.  It is planned to search the area on 7/14 when the weather is forecasted to be warmer and clearer.
# 49,"Zone aircraft N222ME flew the fire and reported a 10 percent active perimeter.  Active burning was observed on the NE, NW and SE corners of the fire.  The fire continues to burn north of the Colleen River and west of Lois Creek.  Increase in acres reflects newer perimeter data."
# 51,"Resources are facing a very active fire while protecting a cabin and 2 allotments.  Eight smokejumpers have been placed on the eastern portion of the allotments and are planning to burn out the area either late tonight or in the morning. The remaining 8 smokejumpers are prepping the rest of the allotments with hose lay and plumbing.  Zone aircraft H-361EH assisted the fire with supplies and bucket drops while N864SF assisted the smokejumpers on the ground with aerial observations and updates of the fire activity.  Depending on the success of the burnout operations, the fire could be mopped up within a few days time."
# 52,The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.
# 55,"Zone surveillance in aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering along the ridgetop. No additional growth was visible. The fire remained 2.15 miles northeast of a National Park Service cabin. Decrease in acreage due to more accurate mapping."
# 58,Identified areas of growth using Landsat 8 image acquired 7/11 @ 2300.  Updated size to 3130 acres.
# 59,Zone surveillance in aircraft N309VS flew the fire and reported no active perimeter. The western interior of the fire was smoldering.
# 61,Fire was flown by zone detection aircraft N222ME and no visible smoke or active perimeter was observed. Update in acreage is due to more accurate mapping.
# 62,Zone surveillance aircraft N22ME flew the fire and reported no activity. Observations were taken under clear skies.

# %%
df_current.to_csv('current.csv', sep='\t')

# %%
reload(blm)
# Out:
# <module 'blmfire' from '/Users/chris/Dropbox/Coding/Python/aiccfiredata/blmfire.py'>

# %%
import pandas as pd

# %% [markdown]
# ## Test JavaScript generation

# %%
FIRETEMPLATE = 'templates/firetemplate.js'
HTMLTEMPLATE = 'templates/current_fires_template.js'

# %%
data = blm.get_raw_fire_data(testfile_current, tryremote=False)
fieldnames = blm.sanitize_dataline(data[0], blanks=3, lower=True)
rawdata = [blm.sanitize_dataline(
            item.strip(), blanks=2, lower=False) for item in data[1::2]]

# the transformed data will be a list of dictionaries
data = blm.get_firedata(fieldnames, rawdata)
finalfirelist = blm.select_relevant_values(data)

# %%
finalfirelist
# Out:
# [{'acreage': '178.2',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'North Hills',
#   'discovered': '08 Jun 2017, 06:00',
#   'lastupdated': '09 Jul 2017, 01:17',
#   'latitude': '62.1606667',
#   'longitude': '-163.1690833',
#   'maintext': 'Decrease in acreage with updated perimeter.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '4.7',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Kowlak',
#   'discovered': '28 Jun 2017, 09:36',
#   'lastupdated': '04 Jul 2017, 02:47',
#   'latitude': '69.9508333',
#   'longitude': '-157.8397222',
#   'maintext': 'Decrease in acreage due to new LandSat perimeter.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '20',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Garnet Creek',
#   'discovered': '06 Jul 2017, 08:29',
#   'lastupdated': '13 Jul 2017, 11:25',
#   'latitude': '65.3315',
#   'longitude': '-150.6751667',
#   'maintext': 'Zone surveillance aircraft N309VS flew the fire and reported no visible smoke.',
#   'numberpeople': '0',
#   'primaryfueltype': '',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '332',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Dietrich River',
#   'discovered': '05 Jul 2017, 03:00',
#   'lastupdated': '13 Jul 2017, 13:06',
#   'latitude': '67.8851389',
#   'longitude': '-149.8075556',
#   'maintext': 'On 7/13, the fire received precipitation and no dominant smokes were visible from the highway; however, drift smoke was present in the area. An unmanned UAS flew the fire and captured infrared images indicating areas of heat. On 7/14, all resources will demobilize from the fire and the fire will remain in monitor status. Fire size decreased to 332 acres due to more accurate mapping.',
#   'numberpeople': '5',
#   'primaryfueltype': '',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '332',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'Blair Lakes',
#   'discovered': '01 Jun 2017, 05:52',
#   'lastupdated': '04 Jul 2017, 14:11',
#   'latitude': '64.3393333',
#   'longitude': '-147.4405',
#   'maintext': 'Zone detection aircraft N309VS flew the fire today. No smoke was observed. The fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '25',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Medicine Lake',
#   'discovered': '05 Jul 2017, 08:00',
#   'lastupdated': '07 Jul 2017, 09:51',
#   'latitude': '65.4828333',
#   'longitude': '-144.4725',
#   'maintext': 'Fire was flown by zone surveillance aircraft N9011N and confirmed at 25 acres with no visible smoke. The fire plotted in a Limited suppression area and will be monitored by zone aircraft.',
#   'numberpeople': '0',
#   'primaryfueltype': '',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '22227.3',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Helmet',
#   'discovered': '06 Jul 2017, 05:55',
#   'lastupdated': '14 Jul 2017, 01:48',
#   'latitude': '67.5596667',
#   'longitude': '-144.0433333',
#   'maintext': 'Zone surveillance aircraft N222ME flew the area of the fire but was unable to observe it due to heavy smoke.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '4',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Vunle Lakes',
#   'discovered': '08 Jul 2017, 02:57',
#   'lastupdated': '12 Jul 2017, 09:44',
#   'latitude': '66.4856667',
#   'longitude': '-143.6733334',
#   'maintext': 'The fire was demobilized and placed into monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '235.4',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Paddle Creek',
#   'discovered': '06 Jul 2017, 07:26',
#   'lastupdated': '10 Jul 2017, 22:31',
#   'latitude': '65.8865',
#   'longitude': '-143.5688333',
#   'maintext': 'Flown today by N222ME. The fire perimeter was 30% active, smoldering in tundra. Observed a 50 + acres increase to the west.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '10188.8',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Bear Mountain',
#   'discovered': '09 Jul 2017, 00:45',
#   'lastupdated': '14 Jul 2017, 01:47',
#   'latitude': '65.9666666',
#   'longitude': '-142.85',
#   'maintext': 'Zone surveillance aircraft N222ME flew the fire and reported it with a 10 percent active perimeter. The fire behavior was described as smoldering in a spruce/hardwood/brush mix. Observations were taken under 40 percent cloud cover.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '1',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Gardiner Creek 2',
#   'discovered': '07 Jul 2017, 07:25',
#   'lastupdated': '09 Jul 2017, 22:34',
#   'latitude': '63.0870278',
#   'longitude': '-141.3386667',
#   'maintext': 'The fire was flown today during a detection flight.  No flames and no smoke was visible.  The fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed (Hardwoods/Softwoods)',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '21.8',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Pass Creek',
#   'discovered': '18 Jun 2017, 05:34',
#   'lastupdated': '13 Jul 2017, 07:29',
#   'latitude': '65.0452778',
#   'longitude': '-141.215',
#   'maintext': 'The fire was flown by zone aircraft N22ME. No smoke, growth or active perimeter was reported.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Brush',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '23673.6',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Ammerman Creek',
#   'discovered': '23 Jun 2017, 09:05',
#   'lastupdated': '13 Jul 2017, 10:51',
#   'latitude': '68.4175833',
#   'longitude': '-141.3226944',
#   'maintext': 'Zone aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering and creeping.  Personnel on board identified the largest amount activity on the southeast corner.  The fire remains west of Ammerman Creek and north of the Old Crow River.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '514',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Andreafsky',
#   'discovered': '08 Jun 2017, 04:45',
#   'lastupdated': '08 Jul 2017, 23:05',
#   'latitude': '62.2646667',
#   'longitude': '-163.021',
#   'maintext': 'Decrease in acreage is due to more accurate mapping.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '25',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Point Lay',
#   'discovered': '28 Jun 2017, 06:44',
#   'lastupdated': '11 Jul 2017, 11:31',
#   'latitude': '69.6728334',
#   'longitude': '-162.8638334',
#   'maintext': 'The Assistant Director of the North Slope Fire Department Borough in Barrow, received a smoke report from locals in Point Lay.  Several thunderstorms and lightning had moved through the area and locals were seeing a large plume of white smoke approximately 5-6 miles SE of Point Lay.  N864SF responded to the smoke report from Kotzebue and confirmed a 25 acre tundra fire of DOF ownership, plotting in Limited.  The fire is currently being held up by 2 water sources on the north and east ends of the fire and will continue to spread south and west.  There are currently no values at risk, so the fire will remain in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '1016',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'East Fork',
#   'discovered': '15 Jun 2017, 10:25',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '60.596333',
#   'longitude': '-150.521167',
#   'maintext': 'Two recon flights were conducted over fire 231, neither found smoke. Personnel took approximately four tons of equipment and supplies off the fire by helicopter and ground. None of the connected suppression equipment was dismantled or taken off the fire.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Dead White Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '30',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Sand Hills',
#   'discovered': '06 Jul 2017, 07:25',
#   'lastupdated': '08 Jul 2017, 14:28',
#   'latitude': '66.333',
#   'longitude': '-148.129',
#   'maintext': 'At 1450 the fire was flown by zone helicopter H-73HJ. The fire was 100 percent active burning in black spruce. Observed fire behavior included running, crowning, torching, and spotting approximately 200 yards ahead. The fire size had increased to approximately 30 acres.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '8344.9',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'South Fork Salcha',
#   'discovered': '08 Jun 2017, 03:09',
#   'lastupdated': '09 Jul 2017, 22:35',
#   'latitude': '64.4436389',
#   'longitude': '-145.5533889',
#   'maintext': 'H-120SH flew the fire, 1 acre of growth was noted on the northside, no other smokes found.  Fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed (Hardwoods/Softwoods)',
#   'structuresburned': '0',
#   'structuresthreatened': '3'},
#  {'acreage': '1',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Loper 2',
#   'discovered': '09 Jul 2017, 03:37',
#   'lastupdated': '09 Jul 2017, 10:48',
#   'latitude': '65.57975',
#   'longitude': '-145.7041667',
#   'maintext': 'The fire was discovered by Zone surveillance aircraft N309VS. The fire was 1 acre in tundra with no active perimeter or smokes showing. The fire plotted in Limited and was placed in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '14.6',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Charley',
#   'discovered': '28 Jun 2017, 08:04',
#   'lastupdated': '09 Jul 2017, 08:15',
#   'latitude': '65.6901667',
#   'longitude': '-143.0935',
#   'maintext': 'At 1315 the fire was flown by zone surveillance aircraft N9011N. No smokes were visible and no change observed.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2.8',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'East Tetlin',
#   'discovered': '10 Jul 2017, 08:12',
#   'lastupdated': '13 Jul 2017, 21:58',
#   'latitude': '63.0278889',
#   'longitude': '-142.2871667',
#   'maintext': 'Fire is contained and controlled, and will be placed into monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed (Hardwoods/Softwoods)',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2876.5',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Dorothy Creek',
#   'discovered': '30 Jun 2017, 07:08',
#   'lastupdated': '13 Jul 2017, 10:50',
#   'latitude': '67.6928056',
#   'longitude': '-142.2386944',
#   'maintext': 'At 1545 zone surveillance aircraft N222ME flew reconnaissance over the fire. No smokes and no active perimeter were observed.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '226.2',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Trout Creek',
#   'discovered': '21 Jun 2017, 11:37',
#   'lastupdated': '12 Jul 2017, 22:07',
#   'latitude': '65.1022222',
#   'longitude': '-141.6383333',
#   'maintext': 'Increase in acreage matches latest perimeter.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed Trees',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '45521.7',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Campbell River',
#   'discovered': '26 Jun 2017, 09:14',
#   'lastupdated': '13 Jul 2017, 13:05',
#   'latitude': '67.2183056',
#   'longitude': '-141.0150278',
#   'maintext': 'At 1500 the fire was flown by zone surveillance aircraft N222ME. The fire was 25 percent active and was spreading to the north. Observed fire behavior included backing and torching in black spruce with 10 foot flame lengths. Weather observed included wind out of the north at 10 mph with 10 percent cloud cover and no precipitation.  Fire is most active on the SW edge.  A 12 mile line of fire has burned 2.10 miles south of the Salmon Trout allotment.   Resources on scene of the allotment and cabin continued to monitor weather and fuel conditions in preparation for a burnout operation. Higher relative humidities kept fuels damp and no burn was attempted. The Midnight Sun IHC began to pretreat areas around the allotment with water.  Tommorow personnel will continue monitoring conditions. A helicopter reconnaissance flight has been scheduled for tomorrow (7/14).',
#   'numberpeople': '35',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '0.5',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'Coal Creek 17',
#   'discovered': '06 Jun 2017, 02:01',
#   'lastupdated': '07 Jul 2017, 05:18',
#   'latitude': '64.0361333',
#   'longitude': '-148.5646333',
#   'maintext': 'H120SH flew fire, currently 1/2 acre barely smoking.  Little to no spread.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '1.5',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'Coal Creek South',
#   'discovered': '06 Jun 2017, 04:18',
#   'lastupdated': '07 Jul 2017, 05:10',
#   'latitude': '64.029783',
#   'longitude': '-148.56375',
#   'maintext': 'H120SH flew fire, currently 1.5 acres, 1-2` flame lengths on the uphill west side.  No action taken, remaining in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '0.4',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'Live Valley',
#   'discovered': '16 Jun 2017, 04:56',
#   'lastupdated': '17 Jun 2017, 02:41',
#   'latitude': '64.7073889',
#   'longitude': '-146.5471111',
#   'maintext': 'Range Control reported the fire as two small grass fires adjacent to one another and just under one half acre in size. Skies were overcast with a 7 mph SSW wind. Zone detection aircraft N9011N flew a reconnaissance mission over the area in the evening but were unable to locate any sign of the fire.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Grass',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '23383.9',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Boulder Creek',
#   'discovered': '02 Jul 2017, 07:12',
#   'lastupdated': '14 Jul 2017, 01:49',
#   'latitude': '67.45',
#   'longitude': '-143.7333333',
#   'maintext': 'Zone surveillance aircraft N222ME flew the fire and reported it with a 30 percent active perimeter and spreading to the north. The fire was creeping and backing with isolated torching in black spruce. Observations were taken under 30 percent cloud cover with calm winds.   Personnel on the ground continued to improve upon the saw line around the allotment. An UAS (unmanned aircraft system) was launched and performed a recon over the fire.',
#   'numberpeople': '75',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2583.5',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Allen',
#   'discovered': '07 Jun 2017, 00:03',
#   'lastupdated': '09 Jul 2017, 01:13',
#   'latitude': '62.5551667',
#   'longitude': '-163.1535',
#   'maintext': 'Increase in acreage due to uploaded perimeter.',
#   'numberpeople': '0',
#   'primaryfueltype': '',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '5.2',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Wolf Creek',
#   'discovered': '03 Jun 2017, 11:11',
#   'lastupdated': '04 Jul 2017, 03:49',
#   'latitude': '62.2952778',
#   'longitude': '-161.4383333',
#   'maintext': 'Change in acreage due to more accurate, digitized mapping.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '16514',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Little Yetna River',
#   'discovered': '04 Jun 2017, 07:52',
#   'lastupdated': '13 Jul 2017, 20:04',
#   'latitude': '62.570333',
#   'longitude': '-158.577333',
#   'maintext': 'The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '4.2',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'Kobe Field',
#   'discovered': '27 Jun 2017, 19:40',
#   'lastupdated': '07 Jul 2017, 05:02',
#   'latitude': '64.25645',
#   'longitude': '-149.354467',
#   'maintext': 'Prevention engine checked fire, found smoke in the NE corner of the slop over.  Added water, will have Forestry engine check 7/4/17.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '3',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Old Lost Creek',
#   'discovered': '07 Jul 2017, 06:52',
#   'lastupdated': '08 Jul 2017, 10:01',
#   'latitude': '66.0363333',
#   'longitude': '-148.0646667',
#   'maintext': 'At 1350 the fire was flown by zone surveillance aircraft N9011N. The fire was active with 3 foot flame lengths. Single tree torching was observed. Fire size had increased to approximately 3 acres.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '74.8',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Preacher Creek',
#   'discovered': '08 Jul 2017, 04:19',
#   'lastupdated': '11 Jul 2017, 14:52',
#   'latitude': '65.95',
#   'longitude': '-144.8',
#   'maintext': 'Increase in acreage from updated infrared imaging.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '322.6',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Deadmans Slough',
#   'discovered': '04 Jun 2017, 11:22',
#   'lastupdated': '23 Jun 2017, 23:49',
#   'latitude': '62.6342222',
#   'longitude': '-160.2121944',
#   'maintext': 'As off 1100, the fire has been called controlled and placed into monitor status. All resources have been demobilized from this fire.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed Trees',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '51.6',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Tenmile',
#   'discovered': '07 Jun 2017, 11:17',
#   'lastupdated': '27 Jun 2017, 02:40',
#   'latitude': '64.0763889',
#   'longitude': '-159.5341667',
#   'maintext': 'Decrease in acreage due to more accurate mapping.',
#   'numberpeople': '0',
#   'primaryfueltype': '',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '12945',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'American Creek',
#   'discovered': '04 Jun 2017, 06:59',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '63.173333',
#   'longitude': '-156.842833',
#   'maintext': 'The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '338.6',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'White Snow',
#   'discovered': '04 Jul 2017, 08:40',
#   'lastupdated': '14 Jul 2017, 01:48',
#   'latitude': '67.5953055',
#   'longitude': '-144.0851667',
#   'maintext': 'The fire was flown by surveillance aircraft N222ME. Fire 312 has consumed fire 303.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '45.2',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': '2017 Windfall Mountain Overwinter _1',
#   'discovered': '31 Dec 2016, 15:01',
#   'lastupdated': '07 Jul 2017, 04:46',
#   'latitude': '65.0298056',
#   'longitude': '-141.2518611',
#   'maintext': 'Fire was flown today by zone aircraft N309VS.  The observer on board reported no active perimeter or acreage gain. Some visible smoke within the fissure.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Grass',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '62800.9',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'White Mountain Creek',
#   'discovered': '03 Jul 2017, 06:09',
#   'lastupdated': '14 Jul 2017, 01:48',
#   'latitude': '67.4532778',
#   'longitude': '-141.3181389',
#   'maintext': 'The fire was flown by surveillance aircraft N222ME. The fire area was too smokey to make observations. New fire size result of update imaging.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '1647.4',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Omikmuktusuk',
#   'discovered': '28 Jun 2017, 09:24',
#   'lastupdated': '04 Jul 2017, 03:02',
#   'latitude': '69.679',
#   'longitude': '-159.622',
#   'maintext': 'Increase in acreage due to updated LandSat perimeter.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2870.3',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Ketik River',
#   'discovered': '28 Jun 2017, 09:24',
#   'lastupdated': '04 Jul 2017, 03:03',
#   'latitude': '69.7545',
#   'longitude': '-159.0356667',
#   'maintext': 'Increase in acreage due to new LandSat perimeter.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '127',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Wayne Taylor',
#   'discovered': '25 Jun 2017, 11:53',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '61.019074',
#   'longitude': '-157.429832',
#   'maintext': 'The fire was flown by 35E.  No activity was observed and the fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Dead White Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '16823.9',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Pitka Fork',
#   'discovered': '04 Jun 2017, 09:18',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '62.425',
#   'longitude': '-154.057167',
#   'maintext': 'Personnel began backhauling structure protection equipment.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '30'},
#  {'acreage': '0.2',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'Kroto Creek',
#   'discovered': '06 Jul 2017, 00:07',
#   'lastupdated': '06 Jul 2017, 22:30',
#   'latitude': '62.0549444',
#   'longitude': '-150.43525',
#   'maintext': 'The fire was reported by a private pilot.  Forestry`s helitack responded to the reported coordinates and located a .2 acre smoldering fire.  The helitack crew suppressed the fire and placed it in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2549.3',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Loper Creek',
#   'discovered': '27 Jun 2017, 06:51',
#   'lastupdated': '09 Jul 2017, 10:49',
#   'latitude': '65.6925',
#   'longitude': '-145.5515',
#   'maintext': 'Fire flown by Zone aircraft N309VS, personnel on board reported no visible smokes.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '1',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'WL 543T',
#   'discovered': '13 Jul 2017, 09:15',
#   'lastupdated': '14 Jul 2017, 01:39',
#   'latitude': '67.0030278',
#   'longitude': '-144.6955833',
#   'maintext': 'The fire was discovered by zone aircraft N222ME during a detection flight. Personnel on board reported a 1 acre fire, 100 percent active, burning on flat terrain in black spruce. The fire plotted in a Limited suppression area and no values at risk were identified. The Upper Yukon Zone will continue to monitor this fire with aerial resources.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '0',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'George Lake Hills',
#   'discovered': '13 Jul 2017, 00:10',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '63.75',
#   'longitude': '-144.316667',
#   'maintext': 'A small column of smoke was reported to the duty officer around 22:30 on 7/12 by a resident on Sand Lake.  Helitack responded after the fog and mist lifted on 7/13.  The reporter could no longer see any smoke once helitack was launched.  Helicopter 873HL thoroughly scanned the area and did not find any blackened ground or smoke.  It is planned to search the area on 7/14 when the weather is forecasted to be warmer and clearer.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Unknown',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '11757.7',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Rat Creek',
#   'discovered': '29 Jun 2017, 05:11',
#   'lastupdated': '10 Jul 2017, 13:51',
#   'latitude': '66.8833333',
#   'longitude': '-142.4833333',
#   'maintext': 'Zone surveillance aircraft N22ME flew the fire and reported the perimeter to be 5% active, smoldering in tundra. No change is size was observed.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Black Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '27629.4',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Lois Creek',
#   'discovered': '02 Jul 2017, 09:28',
#   'lastupdated': '13 Jul 2017, 10:40',
#   'latitude': '68.2916667',
#   'longitude': '-142.0123333',
#   'maintext': 'Zone aircraft N222ME flew the fire and reported a 10 percent active perimeter.  Active burning was observed on the NE, NW and SE corners of the fire.  The fire continues to burn north of the Colleen River and west of Lois Creek.  Increase in acres reflects newer perimeter data.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tussock',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '11.5',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Pastolik',
#   'discovered': '08 Jun 2017, 12:44',
#   'lastupdated': '27 Jun 2017, 04:16',
#   'latitude': '62.7103889',
#   'longitude': '-163.032',
#   'maintext': 'Increase in acreage due to more accurate mapping',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '514.5',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Khotol',
#   'discovered': '06 Jun 2017, 10:05',
#   'lastupdated': '14 Jul 2017, 01:05',
#   'latitude': '64.3261111',
#   'longitude': '-158.2422222',
#   'maintext': 'Resources are facing a very active fire while protecting a cabin and 2 allotments.  Eight smokejumpers have been placed on the eastern portion of the allotments and are planning to burn out the area either late tonight or in the morning. The remaining 8 smokejumpers are prepping the rest of the allotments with hose lay and plumbing.  Zone aircraft H-361EH assisted the fire with supplies and bucket drops while N864SF assisted the smokejumpers on the ground with aerial observations and updates of the fire activity.  Depending on the success of the burnout operations, the fire could be mopped up within a few days time.',
#   'numberpeople': '16',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '13924',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Ball Creek',
#   'discovered': '04 Jun 2017, 12:53',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '62.468167',
#   'longitude': '-157.64295',
#   'maintext': 'The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Other',
#   'structuresburned': '0',
#   'structuresthreatened': '31'},
#  {'acreage': '491.6',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Narvak Lake',
#   'discovered': '27 Jun 2017, 12:15',
#   'lastupdated': '11 Jul 2017, 12:09',
#   'latitude': '66.946',
#   'longitude': '-155.6475',
#   'maintext': 'Updated acreage due to more accurate mapping.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed Trees',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '832',
#   'cause': 'Human',
#   'current': 'false',
#   'designation': 'North Robertson',
#   'discovered': '01 Jun 2017, 02:21',
#   'lastupdated': '28 Jun 2017, 20:00',
#   'latitude': '63.527733',
#   'longitude': '-143.916883',
#   'maintext': 'The fire was flown today, no smokes were seen. The fire will remain in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Dead White Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '135.8',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Seven Mile',
#   'discovered': '29 Jun 2017, 07:08',
#   'lastupdated': '13 Jul 2017, 07:25',
#   'latitude': '65.4047778',
#   'longitude': '-142.4603889',
#   'maintext': 'Zone surveillance in aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering along the ridgetop. No additional growth was visible. The fire remained 2.15 miles northeast of a National Park Service cabin. Decrease in acreage due to more accurate mapping.',
#   'numberpeople': '0',
#   'primaryfueltype': 'White Spruce',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '306.8',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'North Fork',
#   'discovered': '06 Jun 2017, 12:10',
#   'lastupdated': '27 Jun 2017, 07:27',
#   'latitude': '64.202',
#   'longitude': '-159.9615',
#   'maintext': 'N864SF flew the fire and observed there to be no smokes showing.The fire will remain in monitor status',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2653',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Bell Creek',
#   'discovered': '04 Jun 2017, 11:05',
#   'lastupdated': '13 Jul 2017, 20:03',
#   'latitude': '61.918633',
#   'longitude': '-158.081667',
#   'maintext': 'The fire was flown by 35E.  No activity was observed and the fire remains in monitor status.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Mixed (Hardwoods/Softwoods)',
#   'structuresburned': '0',
#   'structuresthreatened': '55'},
#  {'acreage': '3130',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Kihovilik Creek',
#   'discovered': '27 Jun 2017, 13:15',
#   'lastupdated': '12 Jul 2017, 11:54',
#   'latitude': '66.6346667',
#   'longitude': '-157.1596667',
#   'maintext': 'Identified areas of growth using Landsat 8 image acquired 7/11 @ 2300.  Updated size to 3130 acres.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '90',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Larsen Creek',
#   'discovered': '04 Jul 2017, 08:03',
#   'lastupdated': '13 Jul 2017, 11:35',
#   'latitude': '65.4581667',
#   'longitude': '-151.1717778',
#   'maintext': 'Zone surveillance in aircraft N309VS flew the fire and reported no active perimeter. The western interior of the fire was smoldering.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '0.2',
#   'cause': 'Lightning',
#   'current': 'false',
#   'designation': 'Potholes',
#   'discovered': '28 Jun 2017, 11:02',
#   'lastupdated': '30 Jun 2017, 12:49',
#   'latitude': '63.912',
#   'longitude': '-146.0013333',
#   'maintext': 'Zone detection aircraft N700FW flew the fire area today. Smoke observed in the northeast corner of the 1/4 acre. No change in size.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '426.8',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Monument Creek',
#   'discovered': '05 Jul 2017, 07:22',
#   'lastupdated': '13 Jul 2017, 11:16',
#   'latitude': '68.062',
#   'longitude': '-143.8425833',
#   'maintext': 'Fire was flown by zone detection aircraft N222ME and no visible smoke or active perimeter was observed. Update in acreage is due to more accurate mapping.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'},
#  {'acreage': '2228.8',
#   'cause': 'Lightning',
#   'current': 'true',
#   'designation': 'Lake Creek',
#   'discovered': '02 Jul 2017, 08:07',
#   'lastupdated': '13 Jul 2017, 11:08',
#   'latitude': '67.5075',
#   'longitude': '-142.1595',
#   'maintext': 'Zone surveillance aircraft N22ME flew the fire and reported no activity. Observations were taken under clear skies.',
#   'numberpeople': '0',
#   'primaryfueltype': 'Tundra',
#   'structuresburned': '0',
#   'structuresthreatened': '0'}]

# %%
blm.PROJECTPATH = '.'

# %%
fires = blm.fill_template(finalfirelist, template=FIRETEMPLATE)

# %%
print(fires)
# Out:
# 	fire = {
# 		designation: "North Hills",
# 		center: new google.maps.LatLng(62.1606667, -163.1690833),
# 		acreage: 178.2,
# 		maintext: "Decrease in acreage with updated perimeter.",
# 		lastupdated: "09 Jul 2017, 01:17",
# 		discovered: "08 Jun 2017, 06:00",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Kowlak",
# 		center: new google.maps.LatLng(69.9508333, -157.8397222),
# 		acreage: 4.7,
# 		maintext: "Decrease in acreage due to new LandSat perimeter.",
# 		lastupdated: "04 Jul 2017, 02:47",
# 		discovered: "28 Jun 2017, 09:36",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Garnet Creek",
# 		center: new google.maps.LatLng(65.3315, -150.6751667),
# 		acreage: 20,
# 		maintext: "Zone surveillance aircraft N309VS flew the fire and reported no visible smoke.",
# 		lastupdated: "13 Jul 2017, 11:25",
# 		discovered: "06 Jul 2017, 08:29",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Dietrich River",
# 		center: new google.maps.LatLng(67.8851389, -149.8075556),
# 		acreage: 332,
# 		maintext: "On 7/13, the fire received precipitation and no dominant smokes were visible from the highway; however, drift smoke was present in the area. An unmanned UAS flew the fire and captured infrared images indicating areas of heat. On 7/14, all resources will demobilize from the fire and the fire will remain in monitor status. Fire size decreased to 332 acres due to more accurate mapping.",
# 		lastupdated: "13 Jul 2017, 13:06",
# 		discovered: "05 Jul 2017, 03:00",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Blair Lakes",
# 		center: new google.maps.LatLng(64.3393333, -147.4405),
# 		acreage: 332,
# 		maintext: "Zone detection aircraft N309VS flew the fire today. No smoke was observed. The fire remains in monitor status.",
# 		lastupdated: "04 Jul 2017, 14:11",
# 		discovered: "01 Jun 2017, 05:52",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Medicine Lake",
# 		center: new google.maps.LatLng(65.4828333, -144.4725),
# 		acreage: 25,
# 		maintext: "Fire was flown by zone surveillance aircraft N9011N and confirmed at 25 acres with no visible smoke. The fire plotted in a Limited suppression area and will be monitored by zone aircraft.",
# 		lastupdated: "07 Jul 2017, 09:51",
# 		discovered: "05 Jul 2017, 08:00",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Helmet",
# 		center: new google.maps.LatLng(67.5596667, -144.0433333),
# 		acreage: 22227.3,
# 		maintext: "Zone surveillance aircraft N222ME flew the area of the fire but was unable to observe it due to heavy smoke.",
# 		lastupdated: "14 Jul 2017, 01:48",
# 		discovered: "06 Jul 2017, 05:55",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Vunle Lakes",
# 		center: new google.maps.LatLng(66.4856667, -143.6733334),
# 		acreage: 4,
# 		maintext: "The fire was demobilized and placed into monitor status.",
# 		lastupdated: "12 Jul 2017, 09:44",
# 		discovered: "08 Jul 2017, 02:57",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Paddle Creek",
# 		center: new google.maps.LatLng(65.8865, -143.5688333),
# 		acreage: 235.4,
# 		maintext: "Flown today by N222ME. The fire perimeter was 30% active, smoldering in tundra. Observed a 50 + acres increase to the west.",
# 		lastupdated: "10 Jul 2017, 22:31",
# 		discovered: "06 Jul 2017, 07:26",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Bear Mountain",
# 		center: new google.maps.LatLng(65.9666666, -142.85),
# 		acreage: 10188.8,
# 		maintext: "Zone surveillance aircraft N222ME flew the fire and reported it with a 10 percent active perimeter. The fire behavior was described as smoldering in a spruce/hardwood/brush mix. Observations were taken under 40 percent cloud cover.",
# 		lastupdated: "14 Jul 2017, 01:47",
# 		discovered: "09 Jul 2017, 00:45",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Gardiner Creek 2",
# 		center: new google.maps.LatLng(63.0870278, -141.3386667),
# 		acreage: 1,
# 		maintext: "The fire was flown today during a detection flight.  No flames and no smoke was visible.  The fire remains in monitor status.",
# 		lastupdated: "09 Jul 2017, 22:34",
# 		discovered: "07 Jul 2017, 07:25",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Pass Creek",
# 		center: new google.maps.LatLng(65.0452778, -141.215),
# 		acreage: 21.8,
# 		maintext: "The fire was flown by zone aircraft N22ME. No smoke, growth or active perimeter was reported.",
# 		lastupdated: "13 Jul 2017, 07:29",
# 		discovered: "18 Jun 2017, 05:34",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Ammerman Creek",
# 		center: new google.maps.LatLng(68.4175833, -141.3226944),
# 		acreage: 23673.6,
# 		maintext: "Zone aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering and creeping.  Personnel on board identified the largest amount activity on the southeast corner.  The fire remains west of Ammerman Creek and north of the Old Crow River.",
# 		lastupdated: "13 Jul 2017, 10:51",
# 		discovered: "23 Jun 2017, 09:05",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Andreafsky",
# 		center: new google.maps.LatLng(62.2646667, -163.021),
# 		acreage: 514,
# 		maintext: "Decrease in acreage is due to more accurate mapping.",
# 		lastupdated: "08 Jul 2017, 23:05",
# 		discovered: "08 Jun 2017, 04:45",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Point Lay",
# 		center: new google.maps.LatLng(69.6728334, -162.8638334),
# 		acreage: 25,
# 		maintext: "The Assistant Director of the North Slope Fire Department Borough in Barrow, received a smoke report from locals in Point Lay.  Several thunderstorms and lightning had moved through the area and locals were seeing a large plume of white smoke approximately 5-6 miles SE of Point Lay.  N864SF responded to the smoke report from Kotzebue and confirmed a 25 acre tundra fire of DOF ownership, plotting in Limited.  The fire is currently being held up by 2 water sources on the north and east ends of the fire and will continue to spread south and west.  There are currently no values at risk, so the fire will remain in monitor status.",
# 		lastupdated: "11 Jul 2017, 11:31",
# 		discovered: "28 Jun 2017, 06:44",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "East Fork",
# 		center: new google.maps.LatLng(60.596333, -150.521167),
# 		acreage: 1016,
# 		maintext: "Two recon flights were conducted over fire 231, neither found smoke. Personnel took approximately four tons of equipment and supplies off the fire by helicopter and ground. None of the connected suppression equipment was dismantled or taken off the fire.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "15 Jun 2017, 10:25",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Sand Hills",
# 		center: new google.maps.LatLng(66.333, -148.129),
# 		acreage: 30,
# 		maintext: "At 1450 the fire was flown by zone helicopter H-73HJ. The fire was 100 percent active burning in black spruce. Observed fire behavior included running, crowning, torching, and spotting approximately 200 yards ahead. The fire size had increased to approximately 30 acres.",
# 		lastupdated: "08 Jul 2017, 14:28",
# 		discovered: "06 Jul 2017, 07:25",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "South Fork Salcha",
# 		center: new google.maps.LatLng(64.4436389, -145.5533889),
# 		acreage: 8344.9,
# 		maintext: "H-120SH flew the fire, 1 acre of growth was noted on the northside, no other smokes found.  Fire remains in monitor status.",
# 		lastupdated: "09 Jul 2017, 22:35",
# 		discovered: "08 Jun 2017, 03:09",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Loper 2",
# 		center: new google.maps.LatLng(65.57975, -145.7041667),
# 		acreage: 1,
# 		maintext: "The fire was discovered by Zone surveillance aircraft N309VS. The fire was 1 acre in tundra with no active perimeter or smokes showing. The fire plotted in Limited and was placed in monitor status.",
# 		lastupdated: "09 Jul 2017, 10:48",
# 		discovered: "09 Jul 2017, 03:37",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Charley",
# 		center: new google.maps.LatLng(65.6901667, -143.0935),
# 		acreage: 14.6,
# 		maintext: "At 1315 the fire was flown by zone surveillance aircraft N9011N. No smokes were visible and no change observed.",
# 		lastupdated: "09 Jul 2017, 08:15",
# 		discovered: "28 Jun 2017, 08:04",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "East Tetlin",
# 		center: new google.maps.LatLng(63.0278889, -142.2871667),
# 		acreage: 2.8,
# 		maintext: "Fire is contained and controlled, and will be placed into monitor status.",
# 		lastupdated: "13 Jul 2017, 21:58",
# 		discovered: "10 Jul 2017, 08:12",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Dorothy Creek",
# 		center: new google.maps.LatLng(67.6928056, -142.2386944),
# 		acreage: 2876.5,
# 		maintext: "At 1545 zone surveillance aircraft N222ME flew reconnaissance over the fire. No smokes and no active perimeter were observed.",
# 		lastupdated: "13 Jul 2017, 10:50",
# 		discovered: "30 Jun 2017, 07:08",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Trout Creek",
# 		center: new google.maps.LatLng(65.1022222, -141.6383333),
# 		acreage: 226.2,
# 		maintext: "Increase in acreage matches latest perimeter.",
# 		lastupdated: "12 Jul 2017, 22:07",
# 		discovered: "21 Jun 2017, 11:37",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Campbell River",
# 		center: new google.maps.LatLng(67.2183056, -141.0150278),
# 		acreage: 45521.7,
# 		maintext: "At 1500 the fire was flown by zone surveillance aircraft N222ME. The fire was 25 percent active and was spreading to the north. Observed fire behavior included backing and torching in black spruce with 10 foot flame lengths. Weather observed included wind out of the north at 10 mph with 10 percent cloud cover and no precipitation.  Fire is most active on the SW edge.  A 12 mile line of fire has burned 2.10 miles south of the Salmon Trout allotment.   Resources on scene of the allotment and cabin continued to monitor weather and fuel conditions in preparation for a burnout operation. Higher relative humidities kept fuels damp and no burn was attempted. The Midnight Sun IHC began to pretreat areas around the allotment with water.  Tommorow personnel will continue monitoring conditions. A helicopter reconnaissance flight has been scheduled for tomorrow (7/14).",
# 		lastupdated: "13 Jul 2017, 13:05",
# 		discovered: "26 Jun 2017, 09:14",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Coal Creek 17",
# 		center: new google.maps.LatLng(64.0361333, -148.5646333),
# 		acreage: 0.5,
# 		maintext: "H120SH flew fire, currently 1/2 acre barely smoking.  Little to no spread.",
# 		lastupdated: "07 Jul 2017, 05:18",
# 		discovered: "06 Jun 2017, 02:01",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Coal Creek South",
# 		center: new google.maps.LatLng(64.029783, -148.56375),
# 		acreage: 1.5,
# 		maintext: "H120SH flew fire, currently 1.5 acres, 1-2` flame lengths on the uphill west side.  No action taken, remaining in monitor status.",
# 		lastupdated: "07 Jul 2017, 05:10",
# 		discovered: "06 Jun 2017, 04:18",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Live Valley",
# 		center: new google.maps.LatLng(64.7073889, -146.5471111),
# 		acreage: 0.4,
# 		maintext: "Range Control reported the fire as two small grass fires adjacent to one another and just under one half acre in size. Skies were overcast with a 7 mph SSW wind. Zone detection aircraft N9011N flew a reconnaissance mission over the area in the evening but were unable to locate any sign of the fire.",
# 		lastupdated: "17 Jun 2017, 02:41",
# 		discovered: "16 Jun 2017, 04:56",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Boulder Creek",
# 		center: new google.maps.LatLng(67.45, -143.7333333),
# 		acreage: 23383.9,
# 		maintext: "Zone surveillance aircraft N222ME flew the fire and reported it with a 30 percent active perimeter and spreading to the north. The fire was creeping and backing with isolated torching in black spruce. Observations were taken under 30 percent cloud cover with calm winds.   Personnel on the ground continued to improve upon the saw line around the allotment. An UAS (unmanned aircraft system) was launched and performed a recon over the fire.",
# 		lastupdated: "14 Jul 2017, 01:49",
# 		discovered: "02 Jul 2017, 07:12",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Allen",
# 		center: new google.maps.LatLng(62.5551667, -163.1535),
# 		acreage: 2583.5,
# 		maintext: "Increase in acreage due to uploaded perimeter.",
# 		lastupdated: "09 Jul 2017, 01:13",
# 		discovered: "07 Jun 2017, 00:03",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Wolf Creek",
# 		center: new google.maps.LatLng(62.2952778, -161.4383333),
# 		acreage: 5.2,
# 		maintext: "Change in acreage due to more accurate, digitized mapping.",
# 		lastupdated: "04 Jul 2017, 03:49",
# 		discovered: "03 Jun 2017, 11:11",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Little Yetna River",
# 		center: new google.maps.LatLng(62.570333, -158.577333),
# 		acreage: 16514,
# 		maintext: "The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.",
# 		lastupdated: "13 Jul 2017, 20:04",
# 		discovered: "04 Jun 2017, 07:52",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Kobe Field",
# 		center: new google.maps.LatLng(64.25645, -149.354467),
# 		acreage: 4.2,
# 		maintext: "Prevention engine checked fire, found smoke in the NE corner of the slop over.  Added water, will have Forestry engine check 7/4/17.",
# 		lastupdated: "07 Jul 2017, 05:02",
# 		discovered: "27 Jun 2017, 19:40",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Old Lost Creek",
# 		center: new google.maps.LatLng(66.0363333, -148.0646667),
# 		acreage: 3,
# 		maintext: "At 1350 the fire was flown by zone surveillance aircraft N9011N. The fire was active with 3 foot flame lengths. Single tree torching was observed. Fire size had increased to approximately 3 acres.",
# 		lastupdated: "08 Jul 2017, 10:01",
# 		discovered: "07 Jul 2017, 06:52",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Preacher Creek",
# 		center: new google.maps.LatLng(65.95, -144.8),
# 		acreage: 74.8,
# 		maintext: "Increase in acreage from updated infrared imaging.",
# 		lastupdated: "11 Jul 2017, 14:52",
# 		discovered: "08 Jul 2017, 04:19",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Deadmans Slough",
# 		center: new google.maps.LatLng(62.6342222, -160.2121944),
# 		acreage: 322.6,
# 		maintext: "As off 1100, the fire has been called controlled and placed into monitor status. All resources have been demobilized from this fire.",
# 		lastupdated: "23 Jun 2017, 23:49",
# 		discovered: "04 Jun 2017, 11:22",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Tenmile",
# 		center: new google.maps.LatLng(64.0763889, -159.5341667),
# 		acreage: 51.6,
# 		maintext: "Decrease in acreage due to more accurate mapping.",
# 		lastupdated: "27 Jun 2017, 02:40",
# 		discovered: "07 Jun 2017, 11:17",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "American Creek",
# 		center: new google.maps.LatLng(63.173333, -156.842833),
# 		acreage: 12945,
# 		maintext: "The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "04 Jun 2017, 06:59",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "White Snow",
# 		center: new google.maps.LatLng(67.5953055, -144.0851667),
# 		acreage: 338.6,
# 		maintext: "The fire was flown by surveillance aircraft N222ME. Fire 312 has consumed fire 303.",
# 		lastupdated: "14 Jul 2017, 01:48",
# 		discovered: "04 Jul 2017, 08:40",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "2017 Windfall Mountain Overwinter _1",
# 		center: new google.maps.LatLng(65.0298056, -141.2518611),
# 		acreage: 45.2,
# 		maintext: "Fire was flown today by zone aircraft N309VS.  The observer on board reported no active perimeter or acreage gain. Some visible smoke within the fissure.",
# 		lastupdated: "07 Jul 2017, 04:46",
# 		discovered: "31 Dec 2016, 15:01",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "White Mountain Creek",
# 		center: new google.maps.LatLng(67.4532778, -141.3181389),
# 		acreage: 62800.9,
# 		maintext: "The fire was flown by surveillance aircraft N222ME. The fire area was too smokey to make observations. New fire size result of update imaging.",
# 		lastupdated: "14 Jul 2017, 01:48",
# 		discovered: "03 Jul 2017, 06:09",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Omikmuktusuk",
# 		center: new google.maps.LatLng(69.679, -159.622),
# 		acreage: 1647.4,
# 		maintext: "Increase in acreage due to updated LandSat perimeter.",
# 		lastupdated: "04 Jul 2017, 03:02",
# 		discovered: "28 Jun 2017, 09:24",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Ketik River",
# 		center: new google.maps.LatLng(69.7545, -159.0356667),
# 		acreage: 2870.3,
# 		maintext: "Increase in acreage due to new LandSat perimeter.",
# 		lastupdated: "04 Jul 2017, 03:03",
# 		discovered: "28 Jun 2017, 09:24",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Wayne Taylor",
# 		center: new google.maps.LatLng(61.019074, -157.429832),
# 		acreage: 127,
# 		maintext: "The fire was flown by 35E.  No activity was observed and the fire remains in monitor status.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "25 Jun 2017, 11:53",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Pitka Fork",
# 		center: new google.maps.LatLng(62.425, -154.057167),
# 		acreage: 16823.9,
# 		maintext: "Personnel began backhauling structure protection equipment.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "04 Jun 2017, 09:18",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Kroto Creek",
# 		center: new google.maps.LatLng(62.0549444, -150.43525),
# 		acreage: 0.2,
# 		maintext: "The fire was reported by a private pilot.  Forestry`s helitack responded to the reported coordinates and located a .2 acre smoldering fire.  The helitack crew suppressed the fire and placed it in monitor status.",
# 		lastupdated: "06 Jul 2017, 22:30",
# 		discovered: "06 Jul 2017, 00:07",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Loper Creek",
# 		center: new google.maps.LatLng(65.6925, -145.5515),
# 		acreage: 2549.3,
# 		maintext: "Fire flown by Zone aircraft N309VS, personnel on board reported no visible smokes.",
# 		lastupdated: "09 Jul 2017, 10:49",
# 		discovered: "27 Jun 2017, 06:51",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "WL 543T",
# 		center: new google.maps.LatLng(67.0030278, -144.6955833),
# 		acreage: 1,
# 		maintext: "The fire was discovered by zone aircraft N222ME during a detection flight. Personnel on board reported a 1 acre fire, 100 percent active, burning on flat terrain in black spruce. The fire plotted in a Limited suppression area and no values at risk were identified. The Upper Yukon Zone will continue to monitor this fire with aerial resources.",
# 		lastupdated: "14 Jul 2017, 01:39",
# 		discovered: "13 Jul 2017, 09:15",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "George Lake Hills",
# 		center: new google.maps.LatLng(63.75, -144.316667),
# 		acreage: 0,
# 		maintext: "A small column of smoke was reported to the duty officer around 22:30 on 7/12 by a resident on Sand Lake.  Helitack responded after the fog and mist lifted on 7/13.  The reporter could no longer see any smoke once helitack was launched.  Helicopter 873HL thoroughly scanned the area and did not find any blackened ground or smoke.  It is planned to search the area on 7/14 when the weather is forecasted to be warmer and clearer.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "13 Jul 2017, 00:10",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Rat Creek",
# 		center: new google.maps.LatLng(66.8833333, -142.4833333),
# 		acreage: 11757.7,
# 		maintext: "Zone surveillance aircraft N22ME flew the fire and reported the perimeter to be 5% active, smoldering in tundra. No change is size was observed.",
# 		lastupdated: "10 Jul 2017, 13:51",
# 		discovered: "29 Jun 2017, 05:11",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Lois Creek",
# 		center: new google.maps.LatLng(68.2916667, -142.0123333),
# 		acreage: 27629.4,
# 		maintext: "Zone aircraft N222ME flew the fire and reported a 10 percent active perimeter.  Active burning was observed on the NE, NW and SE corners of the fire.  The fire continues to burn north of the Colleen River and west of Lois Creek.  Increase in acres reflects newer perimeter data.",
# 		lastupdated: "13 Jul 2017, 10:40",
# 		discovered: "02 Jul 2017, 09:28",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Pastolik",
# 		center: new google.maps.LatLng(62.7103889, -163.032),
# 		acreage: 11.5,
# 		maintext: "Increase in acreage due to more accurate mapping",
# 		lastupdated: "27 Jun 2017, 04:16",
# 		discovered: "08 Jun 2017, 12:44",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Khotol",
# 		center: new google.maps.LatLng(64.3261111, -158.2422222),
# 		acreage: 514.5,
# 		maintext: "Resources are facing a very active fire while protecting a cabin and 2 allotments.  Eight smokejumpers have been placed on the eastern portion of the allotments and are planning to burn out the area either late tonight or in the morning. The remaining 8 smokejumpers are prepping the rest of the allotments with hose lay and plumbing.  Zone aircraft H-361EH assisted the fire with supplies and bucket drops while N864SF assisted the smokejumpers on the ground with aerial observations and updates of the fire activity.  Depending on the success of the burnout operations, the fire could be mopped up within a few days time.",
# 		lastupdated: "14 Jul 2017, 01:05",
# 		discovered: "06 Jun 2017, 10:05",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Ball Creek",
# 		center: new google.maps.LatLng(62.468167, -157.64295),
# 		acreage: 13924,
# 		maintext: "The fire was flown by 904AK.  Personnel observed no activity and the fire remains in monitor status.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "04 Jun 2017, 12:53",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Narvak Lake",
# 		center: new google.maps.LatLng(66.946, -155.6475),
# 		acreage: 491.6,
# 		maintext: "Updated acreage due to more accurate mapping.",
# 		lastupdated: "11 Jul 2017, 12:09",
# 		discovered: "27 Jun 2017, 12:15",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "North Robertson",
# 		center: new google.maps.LatLng(63.527733, -143.916883),
# 		acreage: 832,
# 		maintext: "The fire was flown today, no smokes were seen. The fire will remain in monitor status.",
# 		lastupdated: "28 Jun 2017, 20:00",
# 		discovered: "01 Jun 2017, 02:21",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Seven Mile",
# 		center: new google.maps.LatLng(65.4047778, -142.4603889),
# 		acreage: 135.8,
# 		maintext: "Zone surveillance in aircraft N222ME flew the fire and reported a 5 percent active perimeter, smoldering along the ridgetop. No additional growth was visible. The fire remained 2.15 miles northeast of a National Park Service cabin. Decrease in acreage due to more accurate mapping.",
# 		lastupdated: "13 Jul 2017, 07:25",
# 		discovered: "29 Jun 2017, 07:08",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "North Fork",
# 		center: new google.maps.LatLng(64.202, -159.9615),
# 		acreage: 306.8,
# 		maintext: "N864SF flew the fire and observed there to be no smokes showing.The fire will remain in monitor status",
# 		lastupdated: "27 Jun 2017, 07:27",
# 		discovered: "06 Jun 2017, 12:10",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Bell Creek",
# 		center: new google.maps.LatLng(61.918633, -158.081667),
# 		acreage: 2653,
# 		maintext: "The fire was flown by 35E.  No activity was observed and the fire remains in monitor status.",
# 		lastupdated: "13 Jul 2017, 20:03",
# 		discovered: "04 Jun 2017, 11:05",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Kihovilik Creek",
# 		center: new google.maps.LatLng(66.6346667, -157.1596667),
# 		acreage: 3130,
# 		maintext: "Identified areas of growth using Landsat 8 image acquired 7/11 @ 2300.  Updated size to 3130 acres.",
# 		lastupdated: "12 Jul 2017, 11:54",
# 		discovered: "27 Jun 2017, 13:15",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Larsen Creek",
# 		center: new google.maps.LatLng(65.4581667, -151.1717778),
# 		acreage: 90,
# 		maintext: "Zone surveillance in aircraft N309VS flew the fire and reported no active perimeter. The western interior of the fire was smoldering.",
# 		lastupdated: "13 Jul 2017, 11:35",
# 		discovered: "04 Jul 2017, 08:03",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Potholes",
# 		center: new google.maps.LatLng(63.912, -146.0013333),
# 		acreage: 0.2,
# 		maintext: "Zone detection aircraft N700FW flew the fire area today. Smoke observed in the northeast corner of the 1/4 acre. No change in size.",
# 		lastupdated: "30 Jun 2017, 12:49",
# 		discovered: "28 Jun 2017, 11:02",
# 		current: false
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Monument Creek",
# 		center: new google.maps.LatLng(68.062, -143.8425833),
# 		acreage: 426.8,
# 		maintext: "Fire was flown by zone detection aircraft N222ME and no visible smoke or active perimeter was observed. Update in acreage is due to more accurate mapping.",
# 		lastupdated: "13 Jul 2017, 11:16",
# 		discovered: "05 Jul 2017, 07:22",
# 		current: true
# 	};
# 	firemap.push(fire);
# 	fire = {
# 		designation: "Lake Creek",
# 		center: new google.maps.LatLng(67.5075, -142.1595),
# 		acreage: 2228.8,
# 		maintext: "Zone surveillance aircraft N22ME flew the fire and reported no activity. Observations were taken under clear skies.",
# 		lastupdated: "13 Jul 2017, 11:08",
# 		discovered: "02 Jul 2017, 08:07",
# 		current: true
# 	};
# 	firemap.push(fire);

# %% [markdown]
# ## Globbedy-glob glob glob ...

# %%
ALREADYLOADED = 'aiccfilelist.txt'
LASTFIREDATA = 'firedata.pickle'

# %%
try:
    with open(ALREADYLOADED, 'r') as source:
        oldfilelist = [
            fn.strip() for fn in source.readlines()
        ]
except IOError:
    oldfilelist = []
filelist = sorted(
    set(glob.glob('archive/2017*_blmfiredata.txt')) - set(oldfilelist)
)

# %%
for file in filelist:
    print(file)
# Out:
# archive/20170726_025909_blmfiredata.txt
# archive/20170726_035911_blmfiredata.txt
# archive/20170726_045910_blmfiredata.txt
# archive/20170726_055909_blmfiredata.txt
# archive/20170726_065912_blmfiredata.txt
# archive/20170726_135908_blmfiredata.txt
# archive/20170726_145909_blmfiredata.txt
# archive/20170726_155908_blmfiredata.txt
# archive/20170726_165911_blmfiredata.txt
# archive/20170726_175909_blmfiredata.txt
# archive/20170726_185907_blmfiredata.txt
# archive/20170726_195906_blmfiredata.txt
# archive/20170726_205906_blmfiredata.txt
# archive/20170726_215905_blmfiredata.txt
# archive/20170726_225906_blmfiredata.txt
# archive/20170726_235907_blmfiredata.txt
# archive/20170727_005907_blmfiredata.txt
# archive/20170727_015907_blmfiredata.txt

# %%
fieldmap = blm.FIELDMAP
fieldmap['lastupdatedatetime'] = 'firesadmin.dailyfirerecord.lastupdatedatetime'
fieldmap['discoverydatetime'] = 'firesadmin.fire.discoverydatetime'
fieldmap['controldatetime'] = 'firesadmin.fire.controldatetime'
fieldmap['containmentdatetime'] = 'firesadmin.fire.containmentdatetime'
fieldmap['guid'] = 'firesadmin.fire.irwinid'
fieldmap['totalcost'] = 'firesadmin.fire.estimatedtotalcost'
fieldmap['cause'] = 'firesadmin.fire.generalcause'
fieldmap['id'] = 'firesadmin.fire.id'

# %%
len(filelist)
# Out:
# 18

# %%
def getfiredf(filepath):
    data = blm.get_raw_fire_data(filepath, tryremote=False)
    fieldnames = blm.sanitize_dataline(data[0], blanks=3, lower=True)
    rawdata = [blm.sanitize_dataline(
                item.strip(), blanks=2, lower=False) for item in data[1::2]]

    # the transformed data will be a list of dictionaries
    data = blm.get_firedata(fieldnames, rawdata)
    firedf = pd.DataFrame(data, columns=list(fieldmap.values()))
    firedf.columns = [list(fieldmap.keys())]
    firedf = cleanup_df(firedf)
    firedf['id'] = firedf['id'].astype('int')
    firedf.set_index('id', inplace=True)
    return firedf

# %%
def mergefireupdate(basefiredf, newfiredf):
    now = dt.datetime.now()
    for index, row in newfiredf.iterrows():
        try: 
            comparecond = (~(
                basefiredf.loc[index, ['acreage', 'maintext']] == newfiredf.loc[index, ['acreage', 'maintext']])).any()
            if comparecond:
                basefiredf.loc[index, 'prev_acreage'] = basefiredf.loc[index, 'acreage'] 
                basefiredf.loc[index, 'prev_text'] = basefiredf.loc[index, 'maintext'] 
                basefiredf.loc[index, basefields] = newfiredf.loc[index, basefields]
                basefiredf.loc[index, 'updatecount'] += 1
        except KeyError:
                basefiredf.loc[index] = newfiredf.loc[index]
                basefiredf.loc[index, 'updatecount'] = 1
                basefiredf.loc[index, 'prev_acreage'] = np.nan
                basefiredf.loc[index, 'prev_text'] = ''
                basefiredf.loc[index, 'current'] = True
        if ((now - basefiredf.loc[index, 'lastupdatedatetime']).days > 8):
            basefiredf.loc[index, 'current'] = False
    return basefiredf

# %%
try:
    firedf = pd.read_pickle(LASTFIREDATA)
    startidx = 0
except FileNotFoundError:
    firedf = getfiredf(filelist[0])
    firedf['prev_acreage'] = np.nan
    firedf['prev_text'] = ''
    firedf['current'] = True
    firedf['updatecount'] = 1
    startidx = 1

# %%
basefields = list(fieldmap.keys())
basefields.remove('id')

# %%
for fn in filelist[startidx:]:
    print("Opening {}".format(fn))
    try:
        newfiredf = getfiredf(fn)
        newfiredf['prev_acreage'] = np.nan
        newfiredf['prev_text'] = ''
        newfiredf['current'] = True
        newfiredf['updatecount'] = 1
    except IOError:
        continue
    except IndexError:
        continue
    firedf0 = mergefireupdate(firedf, newfiredf)
# Out:
# Opening archive/20170726_025909_blmfiredata.txt
# Opening archive/20170726_035911_blmfiredata.txt
# Opening archive/20170726_045910_blmfiredata.txt
# Opening archive/20170726_055909_blmfiredata.txt
# Opening archive/20170726_065912_blmfiredata.txt
# Opening archive/20170726_135908_blmfiredata.txt
# Opening archive/20170726_145909_blmfiredata.txt
# Opening archive/20170726_155908_blmfiredata.txt
# Opening archive/20170726_165911_blmfiredata.txt
# Opening archive/20170726_175909_blmfiredata.txt
# Opening archive/20170726_185907_blmfiredata.txt
# Opening archive/20170726_195906_blmfiredata.txt
# Opening archive/20170726_205906_blmfiredata.txt
# Opening archive/20170726_215905_blmfiredata.txt
# Opening archive/20170726_225906_blmfiredata.txt
# Opening archive/20170726_235907_blmfiredata.txt
# Opening archive/20170727_005907_blmfiredata.txt
# Opening archive/20170727_015907_blmfiredata.txt

# %%
firedf[firedf['current']][[
    'designation', 'cause', 'acreage', 'prev_acreage', 
    'lastupdatedatetime', 'maintext', 'prev_text', 'longitude', 'latitude']].to_dict('records')
# Out:
# [{'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Salchaket Subdivision',
#   'lastupdatedatetime': NaT,
#   'latitude': '64.39848',
#   'longitude': '-146.777772',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 5.0,
#   'cause': 'Lightning',
#   'designation': 'North Ladue River',
#   'lastupdatedatetime': NaT,
#   'latitude': '63.525883',
#   'longitude': '-140.87755',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Crooked Creek',
#   'lastupdatedatetime': NaT,
#   'latitude': '61.870333',
#   'longitude': '-158.105167',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Boulder Creek',
#   'lastupdatedatetime': NaT,
#   'latitude': '64.9',
#   'longitude': '-144.95',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Parks Pullout',
#   'lastupdatedatetime': NaT,
#   'latitude': '64.757317',
#   'longitude': '-148.3757',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Lac Viex',
#   'lastupdatedatetime': NaT,
#   'latitude': '61.516047',
#   'longitude': '-150.042347',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Hog Heaven',
#   'lastupdatedatetime': NaT,
#   'latitude': '61.925617',
#   'longitude': '-145.428167',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'False Alarm _11',
#   'lastupdatedatetime': NaT,
#   'latitude': '65.200167',
#   'longitude': '-148.054317',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.0,
#   'cause': 'Lightning',
#   'designation': 'George Lake Hills',
#   'lastupdatedatetime': Timestamp('2017-07-13 15:57:52.348000'),
#   'latitude': '63.75',
#   'longitude': '-144.316667',
#   'maintext': 'A small column of smoke was reported to the duty officer around 22:30 on 7/12 by a resident on Sand Lake.  Helitack responded after the fog and mist lifted on 7/13.  The reporter could no longer see any smoke once helitack was launched.  Helicopter 873HL thoroughly scanned the area and did not find any blackened ground or smoke.  It is planned to search the area on 7/14 when the weather is forecasted to be warmer and clearer.',
#   'prev_acreage': 0.0,
#   'prev_text': ''},
#  {'acreage': 3.0,
#   'cause': 'Lightning',
#   'designation': 'WL 543T',
#   'lastupdatedatetime': Timestamp('2017-07-25 18:43:00.342000'),
#   'latitude': '67.0030278',
#   'longitude': '-144.6955833',
#   'maintext': 'The fire was flown by zone surveillance aircraft N9011N. The perimeter was 5 percent active, smoldering in black spruce.',
#   'prev_acreage': 3.0,
#   'prev_text': 'The fire was flown by zone surveillance aircraft N9011N. The perimeter was 20 percent active, smoldering in a spruce and hardwood mix in an old burn.'},
#  {'acreage': 57781.7,
#   'cause': 'Lightning',
#   'designation': 'Nowitna',
#   'lastupdatedatetime': Timestamp('2017-07-26 11:16:00.870000'),
#   'latitude': '64.3746945',
#   'longitude': '-154.1182222',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 48747.4,
#   'prev_text': 'Fire activity today was reported as smoldering on the western side of the fire, with more active smoldering in the upper elevations of the eastern section. Zone detection aircraft N309VS flew the fire in the evening and observed a 55 percent active perimeter smoldering with some single tree torching. The spread of the fire continues in a NE direction.   Smokejumpers on scene continued securing the fire in areas located adjacent to the structures.  Helicopter 32AT flew a reconnaissance mission to assess additional structures in the area and monitor the fire`s growth. Tomorrow resources will continue their efforts of securing areas of concern near structures with additional sawline. Additional supplies have been ordered and will be delivered via helicopter tomorrow.'},
#  {'acreage': 3.6,
#   'cause': 'Lightning',
#   'designation': 'John River',
#   'lastupdatedatetime': Timestamp('2017-07-17 13:02:00.163000'),
#   'latitude': '66.9699166',
#   'longitude': '-151.6166111',
#   'maintext': 'Four smokejumpers were demobilized from this incident and reassigned to fire 344.',
#   'prev_acreage': 3.6,
#   'prev_text': 'After performing a check of the fire in the morning hours, an area of heat was discovered.  The demobilization plan was adjusted to a later date to allow for full suppression of the newly discovered heat. Plans for tomorrow include the demobilization of the all 4 smokejumpers.'},
#  {'acreage': 4244.1,
#   'cause': 'Lightning',
#   'designation': 'Chleca Lakes',
#   'lastupdatedatetime': Timestamp('2017-07-26 12:13:00.951000'),
#   'latitude': '63.7170555',
#   'longitude': '-153.3208611',
#   'maintext': 'Increase in acreage due to more accurate mapping.',
#   'prev_acreage': 2837.2,
#   'prev_text': 'Increase in acreage due to more accurate mapping.'},
#  {'acreage': 22.0,
#   'cause': 'Lightning',
#   'designation': 'Montana Creek',
#   'lastupdatedatetime': Timestamp('2017-07-15 21:16:11.758000'),
#   'latitude': '62.5425',
#   'longitude': '-157.453333',
#   'maintext': 'Fire personnel worked the fire through most the evening, and continued throughout the day. The fire was under 100 percent cloud cover, but never received any precipitation by evening time of 7/15. Tentative demob is planned for tomorrow, 7/16,  around mid afternoon. Acreage change due to gps mapping.',
#   'prev_acreage': 18.0,
#   'prev_text': 'The fire was found by multiple modis spots. BD-840 was launched from Palmer, and sized the fire up as 15 acres, 60 percent active, burning in grass and brush. J-07 responded, deploying 8 jumpers and sizing the fire up as 18 acres and 30 percent active. Personnel will take advantage of the high evening humidity, working late into the evening to help make significant progress towards their full suppression goals.'},
#  {'acreage': 905.6,
#   'cause': 'Lightning',
#   'designation': 'Big Waldren Fork',
#   'lastupdatedatetime': Timestamp('2017-07-24 04:00:08.172000'),
#   'latitude': '62.529034',
#   'longitude': '-156.533152',
#   'maintext': 'The fire was flown by H-212HL.  Personnel reported the fire was burning rank 3 in continuous hardwoods and tundra, 20% active, torching and smoldering with 40` flame lengths.  The fire had increased in size by 250 acres.  There were no resources threatened and the fire remains in monitor status.',
#   'prev_acreage': 900.0,
#   'prev_text': 'The fire was flown by H-212HL.  Personnel reported the fire was burning rank 3 in continuous hardwoods and tundra, 20% active, torching and smoldering with 40` flame lengths.  The fire had increased in size by 250 acres.  There were no resources threatened and the fire remains in monitor status.'},
#  {'acreage': 47.6,
#   'cause': 'Lightning',
#   'designation': 'Alatna Hills',
#   'lastupdatedatetime': Timestamp('2017-07-22 13:39:00.128000'),
#   'latitude': '67.0286667',
#   'longitude': '-152.1536667',
#   'maintext': 'The fire was flown by zone surveillance aircraft N309VS. Personnel on board reported no smokes or change in size.',
#   'prev_acreage': 47.6,
#   'prev_text': 'At 15:24 the fire was flown by zone surveillance aircraft N190PE. The fire had no active perimeter and no smokes were visible.'},
#  {'acreage': 25.0,
#   'cause': 'Lightning',
#   'designation': 'Shuman Lake',
#   'lastupdatedatetime': Timestamp('2017-07-25 19:33:00.977000'),
#   'latitude': '66.9251667',
#   'longitude': '-144.097',
#   'maintext': 'Zone surveillance aircraft N9011N flew the fire and observed the fire smoldering and creeping in white spruce with a 40 percent active perimeter. Winds were calme with 60 percent cloud cover.',
#   'prev_acreage': 20.0,
#   'prev_text': 'Zone surveillance aircraft N9011N flew the fire and observed the fire smoldering and creeping in white spruce with a 40 percent active perimeter. Winds were calme with 60 percent cloud cover.'},
#  {'acreage': 73.3,
#   'cause': 'Lightning',
#   'designation': 'Big Mud River',
#   'lastupdatedatetime': Timestamp('2017-07-26 11:21:00.886000'),
#   'latitude': '64.5605556',
#   'longitude': '-153.2063889',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 25.0,
#   'prev_text': 'Zone surveillance aircraft in N309VS flew the fire and reported it with a 35 percent active perimeter and smoldering in an old burn scar. Observations were taken under 90 percent cloud cover and winds out of the west at 10+ mph. Estimated size increase of 10 acres.'},
#  {'acreage': 11.8,
#   'cause': 'Lightning',
#   'designation': 'Jack White',
#   'lastupdatedatetime': Timestamp('2017-07-22 21:25:00.172000'),
#   'latitude': '66.965',
#   'longitude': '-151.28',
#   'maintext': 'Zone aircraft N309VS flew the fire area and observed no smoke or change in size. Resources performed a final grid of the fire and found no heat.  Helicopter N405AE was utilized to transport excess supplies to Bettles to prepare for demobilization.  All resources will demobilize from the incident tomorrow (7/23).',
#   'prev_acreage': 11.8,
#   'prev_text': 'Zone aircraft N309VS flew the fire area annd observed no smoke or change in size. Resources performed a final grid of the fire and found no heat.  Helicopter N405AE was utilized to transport excess supplies to Bettles to prepare for demobilization.  All resources will demobilize from the incident tomorrow (7/23).'},
#  {'acreage': 98.4,
#   'cause': 'Lightning',
#   'designation': 'Chalatna Creek',
#   'lastupdatedatetime': Timestamp('2017-07-22 12:58:00.281000'),
#   'latitude': '66.484',
#   'longitude': '-151.1151667',
#   'maintext': 'Fire was flown by zone aircraft N309VS and no smoke or changes were observed.',
#   'prev_acreage': 98.4,
#   'prev_text': 'Zone surveillance aircraft N190PE flew the fire and reported no smokes visible.'},
#  {'acreage': 16.6,
#   'cause': 'Lightning',
#   'designation': 'Little Mud',
#   'lastupdatedatetime': Timestamp('2017-07-26 11:22:00.886000'),
#   'latitude': '64.7471667',
#   'longitude': '-152.8089167',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 4.0,
#   'prev_text': 'Zone surveillance aircraft N309VS flew the fire and reported an 100 percent active perimeter, smoldering in an old burn. Observations were taken under cloudy skies and winds out of the west soutwest at 20 mph.'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'SARKAR RIVER BRIDGE',
#   'lastupdatedatetime': Timestamp('2017-07-19 06:37:00.679000'),
#   'latitude': '55.9508333',
#   'longitude': '-133.2344444',
#   'maintext': 'Fire was called in by local citizen 7/18/17 at 0822.  Forest Service personnel responded and worked the fire and called it contained and in monitor status at 1400.  Will recheck tomorrow or next day.  All resources have been released.',
#   'prev_acreage': 0.0,
#   'prev_text': ''},
#  {'acreage': 5.0,
#   'cause': 'Lightning',
#   'designation': 'Essie Creek',
#   'lastupdatedatetime': Timestamp('2017-07-19 06:19:00.679000'),
#   'latitude': '64.9743333',
#   'longitude': '-143.075',
#   'maintext': 'The fire was discovered by Zone aircraft N9011N. The fire is 5 acres with a 0% active perimeter and one interior smoke smoldering on the north side in a mix of white and black spruce. The fire plots in Limited and is placed in monitor status.',
#   'prev_acreage': 5.0,
#   'prev_text': 'The fire was discovered by Zone aircraft N9011N. The fire is 5 acres with a 0% active perimeter and one interior smoke smoldering on the North side in a mix of white and black spruce. The fire plots in limited and is placed in monitor status.'},
#  {'acreage': 3.0,
#   'cause': '',
#   'designation': 'Paddle Creek 2',
#   'lastupdatedatetime': Timestamp('2017-07-18 17:55:00.108000'),
#   'latitude': '65.9113333',
#   'longitude': '-143.2696667',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Hidden Rain',
#   'lastupdatedatetime': Timestamp('2017-07-18 20:37:02.809000'),
#   'latitude': '60.468567',
#   'longitude': '-150.2029',
#   'maintext': 'DOF engine responded to a reported abandoned campfire near Hidden Lake. Upon arrival found a smoldering, rank 1, 5` x 5` fire that was burning in leaf litter and roots.  Engine personnel took suppression action and the fire was contained, controlled, and placed in monitor status.',
#   'prev_acreage': 0.1,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': '33 Mile Loop',
#   'lastupdatedatetime': Timestamp('2017-07-20 08:15:00.266000'),
#   'latitude': '63.9553889',
#   'longitude': '-145.5297222',
#   'maintext': 'A dozer contracted by the military caught fire in the Donnelly Training Area along the 33 Mile Loop road. Range control personnel responded and were able to suppress the fire before it advanced further  into the wildland. Additional resources from Delta responded but were not needed as range control reported they had contained the fire. Range personnel will check the site tomorrow (7/19).',
#   'prev_acreage': 0.1,
#   'prev_text': 'A dozer contracted by the military caught fire in the Donnelly Training Area along the 33 Mile Loop road. Range control personnel responded and were able to suppress the fire before it advanced to the wildland. Additional resources from Delta responded but were not needed as range control reported they had contained the fire. Range personnel will check the site tomorrow (7/19).'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'McCoy Creek',
#   'lastupdatedatetime': Timestamp('2017-07-20 06:36:00.348000'),
#   'latitude': '64.49',
#   'longitude': '-146.356667',
#   'maintext': 'Received a report of a small fire smoldering just east of the pipeline.  H120SH flew the fire and dropped off the helitack load to begin suppression operations.  Fire was a 10 x 10 spot, rank 1 in black spruce 100 percent active.  Fire was extinguished and they began to green grid and cold trail the area.  3 Forestry personnel will remain overnight to ensure no further heats pop up and prepare for demobilization on Thursday.',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Lightning',
#   'designation': 'Wickersham Dome',
#   'lastupdatedatetime': Timestamp('2017-07-25 18:41:00.326000'),
#   'latitude': '65.3423333',
#   'longitude': '-147.6953333',
#   'maintext': 'Zone surveillance aircraft N9011N flew the fire and reported no visible smokes.  Weather in the area was 100 percent cloud cover with light precipitation.',
#   'prev_acreage': 0.1,
#   'prev_text': 'The fire was flown by zone surveillance aircraft N9011N. No smokes were visible.'},
#  {'acreage': 150.0,
#   'cause': 'Lightning',
#   'designation': 'Deadman',
#   'lastupdatedatetime': Timestamp('2017-07-25 18:37:00.342000'),
#   'latitude': '66.5291667',
#   'longitude': '-146.4633333',
#   'maintext': 'Zone detection aircraft N9011N flew a reconnaissance over the fire today. Reported fire behavior is smoldering, creeping, backing with a low rate of spread within a 40 percent active perimeter. Cloud cover estimated at 60 percent and no precipitation.',
#   'prev_acreage': 113.0,
#   'prev_text': 'Update in acreage due to more accurate imagery.'},
#  {'acreage': 3.0,
#   'cause': 'Lightning',
#   'designation': 'Owens',
#   'lastupdatedatetime': Timestamp('2017-07-20 21:46:00.810000'),
#   'latitude': '67.6232778',
#   'longitude': '-143.2066944',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 10.0,
#   'cause': 'Lightning',
#   'designation': 'Sulatna River',
#   'lastupdatedatetime': Timestamp('2017-07-22 21:12:00.188000'),
#   'latitude': '64.59',
#   'longitude': '-154.53',
#   'maintext': 'Zone surveillance aircraft N309VS flew over the area and could not locate any smoke or remnants of a fire. The Tanana Zone will continue to monitor the area with aerial resources.',
#   'prev_acreage': 10.0,
#   'prev_text': 'Fire was initially reported by a private pilot to Flight Services. The fire was estimated at 7-10 acres in size. Galena Zone helicopter 32AT did a flyby of the coordinates and was unable to locate a fire. Zone aircraft N309VS flew the area at 19:30 and was unable to locate the fire. The Tanana Zone will continue to monitor the area with aerial resources.'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'MPMG 19',
#   'lastupdatedatetime': Timestamp('2017-07-21 16:20:00.649000'),
#   'latitude': '64.8023333',
#   'longitude': '-147.6473333',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.2,
#   'cause': 'Lightning',
#   'designation': 'Lower Birch',
#   'lastupdatedatetime': Timestamp('2017-07-23 21:04:00.281000'),
#   'latitude': '66.4308055',
#   'longitude': '-146.8511111',
#   'maintext': 'Personnel mopped up the fire throughout the shift, minimal heat was found. All resources will be demobilized tomorrow (7/24).',
#   'prev_acreage': 0.2,
#   'prev_text': 'Personnel worked to secure the fire line and clean up downed trees. Progress continues through the mop up phase. Tentative demobilization on Monday (7/24).'},
#  {'acreage': 2500.0,
#   'cause': 'Lightning',
#   'designation': 'Forty and One Half',
#   'lastupdatedatetime': Timestamp('2017-07-25 18:47:00.326000'),
#   'latitude': '66.7772778',
#   'longitude': '-147.7153333',
#   'maintext': 'Zone detection aircraft N9011N flew a reconnaissance over the fire today. Reported fire behavior is backing and running at a rate of two chains per hour within a 40 percent active perimeter in black spruce and tundra. Cloud cover estimated at 90 percent and no precipitation.',
#   'prev_acreage': 1029.8,
#   'prev_text': 'Update in acreage due to more accurate imagery.'},
#  {'acreage': 0.4,
#   'cause': 'Human',
#   'designation': 'Louden',
#   'lastupdatedatetime': Timestamp('2017-07-24 17:51:00.767000'),
#   'latitude': '64.6365278',
#   'longitude': '-156.6633333',
#   'maintext': 'N361EH with three firefighters returned to the fire again today.  They located and mopped up 4 interior smokes; 2 of the 4 near the perimeter.  All hose and equipment was pulled off and firefighters returned to Galena.  Will check it again at a later date.',
#   'prev_acreage': 0.4,
#   'prev_text': 'N361EH and three firefighters returned to check fire 361 today.  It was GPS`d at .38 acres.  They located approximately 10 interior wildland smokes; most on the north end and some within 5 feet of the perimeter.  There is some interior heat from heavy fuels in the structure rubble, possibly from wood stacked near the structure.  It does not pose a threat to the line.  Firefighters mopped up interior smokes.  The pump and hose lay will remain in place.  They will check it again at a later date.'},
#  {'acreage': 89.7,
#   'cause': 'Lightning',
#   'designation': 'Echoing',
#   'lastupdatedatetime': Timestamp('2017-07-26 13:50:00.202000'),
#   'latitude': '66.327',
#   'longitude': '-149.309',
#   'maintext': 'Updated perimeter due to digitized mapping.',
#   'prev_acreage': 150.0,
#   'prev_text': 'Zone detection aircraft N9011N flew a reconnaissance over the fire today. Reported fire behavior is running at a rate of one chain per hour within a 40 percent active perimeter in tundra, willow and fireweed. Cloud cover estimated at 80 percent and no precipitation. Fire is moving away from the native allotments 2.5 miles to the south.'},
#  {'acreage': 0.4,
#   'cause': 'Human',
#   'designation': '0.5 Mile Murphy Dome Road',
#   'lastupdatedatetime': Timestamp('2017-07-23 22:43:34.249000'),
#   'latitude': '64.916422',
#   'longitude': '-147.94623',
#   'maintext': 'At 1511, two DOF engines and Chena Goldstream Fire and Rescue responded to a structure fire with wildland involvement on Murphy Dome Road. The structure was fully involved upon arrival and the wildland fire was approximately 0.25 acre in size and burning in black spruce with 1-4 foot flame lengths. The fire was located in a Critical suppression management area and a structure adjacent to the fire was threatened. DOF Helicopter H120SH responded and conducted bucket work over the fire. The fire was contained at 0.4 acres. During the next operational shift, DOF personnel will return to the fire to continue mop up.',
#   'prev_acreage': 0.4,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Lightning',
#   'designation': 'Twelve Mile',
#   'lastupdatedatetime': Timestamp('2017-07-24 06:58:00.913000'),
#   'latitude': '64.1333333',
#   'longitude': '-141.5333334',
#   'maintext': 'This fire was a False Alarm.',
#   'prev_acreage': 0.1,
#   'prev_text': ''},
#  {'acreage': 10.9,
#   'cause': 'Lightning',
#   'designation': 'Chandalar',
#   'lastupdatedatetime': Timestamp('2017-07-26 11:23:00.886000'),
#   'latitude': '66.8376944',
#   'longitude': '-146.1686389',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 20.0,
#   'prev_text': 'Fire was flown by zone aircraft N9011N.  The perimeter was 40 percent active, smoldering and creeping.  The fire has a low rate of spread but continues to burn in all directions.  Weather in the area was 60 percent cloud cover, with winds out of the SW.'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Jakolof Bay',
#   'lastupdatedatetime': Timestamp('2017-07-26 15:48:45.415000'),
#   'latitude': '59.463267',
#   'longitude': '-151.534567',
#   'maintext': 'Fire occurred on 7/24 and Seldovia VFD responded,  fire was reported to be 8`x8` smoldering in grass and duff.  Fire was contained and controlled by VFD and is now in monitor status.',
#   'prev_acreage': 0.1,
#   'prev_text': ''},
#  {'acreage': 0.0,
#   'cause': 'Human',
#   'designation': 'Bear',
#   'lastupdatedatetime': Timestamp('2017-07-26 15:11:51.521000'),
#   'latitude': '60.198833',
#   'longitude': '-149.345833',
#   'maintext': 'Bear Creek VFD responded to a small fire, mainly smoldering stumps, on the island on Bear lake.  Fire was extinguished.  Will be chaecked agian tomorrow.',
#   'prev_acreage': 0.0,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Grand Ave',
#   'lastupdatedatetime': Timestamp('2017-07-26 15:29:42.521000'),
#   'latitude': '61.713533',
#   'longitude': '-148.889683',
#   'maintext': '911 reported a structure fire with possible wildland involvement.  On location Forestry located minimal wildland in fire.  Engine crew members suppressed the fire and placed it on monitor status.',
#   'prev_acreage': nan,
#   'prev_text': ''}]

# %%
def savecurrentstate(filelist, firedf0, outfile, outdataframe):
    with open(outfile, 'w') as dest:
        for line in oldfilelist:
            print(line, file=dest)
        for line in filelist:
            print(line, file=dest)
    firedf0.to_pickle(outdataframe)

# %%
savecurrentstate(filelist, firedf, 'aiccfilelist.txt', 'firedata.pickle')

# %%
sqkm(113, .5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-43e37d02535a> in <module>()
# ----> 1 sqkm(113, .5)
#
# NameError: name 'sqkm' is not defined

# %%
firedf[firedf['current']][[
    'designation', 'cause', 'acreage', 'prev_acreage', 
    'lastupdatedatetime', 'discoverydatetime', 'maintext', 'prev_text', 'longitude', 'latitude']].sort_values(
    by='lastupdatedatetime', ascending=False).to_dict('records')
# Out:
# [{'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Jakolof Bay',
#   'discoverydatetime': Timestamp('2017-07-24 09:26:38.415000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 15:48:45.415000'),
#   'latitude': '59.463267',
#   'longitude': '-151.534567',
#   'maintext': 'Fire occurred on 7/24 and Seldovia VFD responded,  fire was reported to be 8`x8` smoldering in grass and duff.  Fire was contained and controlled by VFD and is now in monitor status.',
#   'prev_acreage': 0.1,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Grand Ave',
#   'discoverydatetime': Timestamp('2017-07-26 13:32:38.521000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 15:29:42.521000'),
#   'latitude': '61.713533',
#   'longitude': '-148.889683',
#   'maintext': '911 reported a structure fire with possible wildland involvement.  On location Forestry located minimal wildland in fire.  Engine crew members suppressed the fire and placed it on monitor status.',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.0,
#   'cause': 'Human',
#   'designation': 'Bear',
#   'discoverydatetime': Timestamp('2017-07-26 14:14:07.521000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 15:11:51.521000'),
#   'latitude': '60.198833',
#   'longitude': '-149.345833',
#   'maintext': 'Bear Creek VFD responded to a small fire, mainly smoldering stumps, on the island on Bear lake.  Fire was extinguished.  Will be chaecked agian tomorrow.',
#   'prev_acreage': 0.0,
#   'prev_text': ''},
#  {'acreage': 89.7,
#   'cause': 'Lightning',
#   'designation': 'Echoing',
#   'discoverydatetime': Timestamp('2017-07-22 17:22:17.202000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 13:50:00.202000'),
#   'latitude': '66.327',
#   'longitude': '-149.309',
#   'maintext': 'Updated perimeter due to digitized mapping.',
#   'prev_acreage': 150.0,
#   'prev_text': 'Zone detection aircraft N9011N flew a reconnaissance over the fire today. Reported fire behavior is running at a rate of one chain per hour within a 40 percent active perimeter in tundra, willow and fireweed. Cloud cover estimated at 80 percent and no precipitation. Fire is moving away from the native allotments 2.5 miles to the south.'},
#  {'acreage': 4244.1,
#   'cause': 'Lightning',
#   'designation': 'Chleca Lakes',
#   'discoverydatetime': Timestamp('2017-07-14 17:39:04.951000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 12:13:00.951000'),
#   'latitude': '63.7170555',
#   'longitude': '-153.3208611',
#   'maintext': 'Increase in acreage due to more accurate mapping.',
#   'prev_acreage': 2837.2,
#   'prev_text': 'Increase in acreage due to more accurate mapping.'},
#  {'acreage': 10.9,
#   'cause': 'Lightning',
#   'designation': 'Chandalar',
#   'discoverydatetime': Timestamp('2017-07-24 19:48:32.886000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 11:23:00.886000'),
#   'latitude': '66.8376944',
#   'longitude': '-146.1686389',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 20.0,
#   'prev_text': 'Fire was flown by zone aircraft N9011N.  The perimeter was 40 percent active, smoldering and creeping.  The fire has a low rate of spread but continues to burn in all directions.  Weather in the area was 60 percent cloud cover, with winds out of the SW.'},
#  {'acreage': 16.6,
#   'cause': 'Lightning',
#   'designation': 'Little Mud',
#   'discoverydatetime': Timestamp('2017-07-17 16:46:55.886000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 11:22:00.886000'),
#   'latitude': '64.7471667',
#   'longitude': '-152.8089167',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 4.0,
#   'prev_text': 'Zone surveillance aircraft N309VS flew the fire and reported an 100 percent active perimeter, smoldering in an old burn. Observations were taken under cloudy skies and winds out of the west soutwest at 20 mph.'},
#  {'acreage': 73.3,
#   'cause': 'Lightning',
#   'designation': 'Big Mud River',
#   'discoverydatetime': Timestamp('2017-07-16 14:41:31.886000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 11:21:00.886000'),
#   'latitude': '64.5605556',
#   'longitude': '-153.2063889',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 25.0,
#   'prev_text': 'Zone surveillance aircraft in N309VS flew the fire and reported it with a 35 percent active perimeter and smoldering in an old burn scar. Observations were taken under 90 percent cloud cover and winds out of the west at 10+ mph. Estimated size increase of 10 acres.'},
#  {'acreage': 57781.7,
#   'cause': 'Lightning',
#   'designation': 'Nowitna',
#   'discoverydatetime': Timestamp('2017-07-14 13:41:03.870000'),
#   'lastupdatedatetime': Timestamp('2017-07-26 11:16:00.870000'),
#   'latitude': '64.3746945',
#   'longitude': '-154.1182222',
#   'maintext': 'Update in acreage due to more accurate mapping.',
#   'prev_acreage': 48747.4,
#   'prev_text': 'Fire activity today was reported as smoldering on the western side of the fire, with more active smoldering in the upper elevations of the eastern section. Zone detection aircraft N309VS flew the fire in the evening and observed a 55 percent active perimeter smoldering with some single tree torching. The spread of the fire continues in a NE direction.   Smokejumpers on scene continued securing the fire in areas located adjacent to the structures.  Helicopter 32AT flew a reconnaissance mission to assess additional structures in the area and monitor the fire`s growth. Tomorrow resources will continue their efforts of securing areas of concern near structures with additional sawline. Additional supplies have been ordered and will be delivered via helicopter tomorrow.'},
#  {'acreage': 25.0,
#   'cause': 'Lightning',
#   'designation': 'Shuman Lake',
#   'discoverydatetime': Timestamp('2017-07-15 18:44:40.977000'),
#   'lastupdatedatetime': Timestamp('2017-07-25 19:33:00.977000'),
#   'latitude': '66.9251667',
#   'longitude': '-144.097',
#   'maintext': 'Zone surveillance aircraft N9011N flew the fire and observed the fire smoldering and creeping in white spruce with a 40 percent active perimeter. Winds were calme with 60 percent cloud cover.',
#   'prev_acreage': 20.0,
#   'prev_text': 'Zone surveillance aircraft N9011N flew the fire and observed the fire smoldering and creeping in white spruce with a 40 percent active perimeter. Winds were calme with 60 percent cloud cover.'},
#  {'acreage': 2500.0,
#   'cause': 'Lightning',
#   'designation': 'Forty and One Half',
#   'discoverydatetime': Timestamp('2017-07-21 18:01:39.326000'),
#   'lastupdatedatetime': Timestamp('2017-07-25 18:47:00.326000'),
#   'latitude': '66.7772778',
#   'longitude': '-147.7153333',
#   'maintext': 'Zone detection aircraft N9011N flew a reconnaissance over the fire today. Reported fire behavior is backing and running at a rate of two chains per hour within a 40 percent active perimeter in black spruce and tundra. Cloud cover estimated at 90 percent and no precipitation.',
#   'prev_acreage': 1029.8,
#   'prev_text': 'Update in acreage due to more accurate imagery.'},
#  {'acreage': 3.0,
#   'cause': 'Lightning',
#   'designation': 'WL 543T',
#   'discoverydatetime': Timestamp('2017-07-13 17:15:04.342000'),
#   'lastupdatedatetime': Timestamp('2017-07-25 18:43:00.342000'),
#   'latitude': '67.0030278',
#   'longitude': '-144.6955833',
#   'maintext': 'The fire was flown by zone surveillance aircraft N9011N. The perimeter was 5 percent active, smoldering in black spruce.',
#   'prev_acreage': 3.0,
#   'prev_text': 'The fire was flown by zone surveillance aircraft N9011N. The perimeter was 20 percent active, smoldering in a spruce and hardwood mix in an old burn.'},
#  {'acreage': 0.1,
#   'cause': 'Lightning',
#   'designation': 'Wickersham Dome',
#   'discoverydatetime': Timestamp('2017-07-20 09:46:37.326000'),
#   'lastupdatedatetime': Timestamp('2017-07-25 18:41:00.326000'),
#   'latitude': '65.3423333',
#   'longitude': '-147.6953333',
#   'maintext': 'Zone surveillance aircraft N9011N flew the fire and reported no visible smokes.  Weather in the area was 100 percent cloud cover with light precipitation.',
#   'prev_acreage': 0.1,
#   'prev_text': 'The fire was flown by zone surveillance aircraft N9011N. No smokes were visible.'},
#  {'acreage': 150.0,
#   'cause': 'Lightning',
#   'designation': 'Deadman',
#   'discoverydatetime': Timestamp('2017-07-20 09:45:32.342000'),
#   'lastupdatedatetime': Timestamp('2017-07-25 18:37:00.342000'),
#   'latitude': '66.5291667',
#   'longitude': '-146.4633333',
#   'maintext': 'Zone detection aircraft N9011N flew a reconnaissance over the fire today. Reported fire behavior is smoldering, creeping, backing with a low rate of spread within a 40 percent active perimeter. Cloud cover estimated at 60 percent and no precipitation.',
#   'prev_acreage': 113.0,
#   'prev_text': 'Update in acreage due to more accurate imagery.'},
#  {'acreage': 0.4,
#   'cause': 'Human',
#   'designation': 'Louden',
#   'discoverydatetime': Timestamp('2017-07-22 15:22:49.767000'),
#   'lastupdatedatetime': Timestamp('2017-07-24 17:51:00.767000'),
#   'latitude': '64.6365278',
#   'longitude': '-156.6633333',
#   'maintext': 'N361EH with three firefighters returned to the fire again today.  They located and mopped up 4 interior smokes; 2 of the 4 near the perimeter.  All hose and equipment was pulled off and firefighters returned to Galena.  Will check it again at a later date.',
#   'prev_acreage': 0.4,
#   'prev_text': 'N361EH and three firefighters returned to check fire 361 today.  It was GPS`d at .38 acres.  They located approximately 10 interior wildland smokes; most on the north end and some within 5 feet of the perimeter.  There is some interior heat from heavy fuels in the structure rubble, possibly from wood stacked near the structure.  It does not pose a threat to the line.  Firefighters mopped up interior smokes.  The pump and hose lay will remain in place.  They will check it again at a later date.'},
#  {'acreage': 0.1,
#   'cause': 'Lightning',
#   'designation': 'Twelve Mile',
#   'discoverydatetime': Timestamp('2017-07-23 17:34:08.913000'),
#   'lastupdatedatetime': Timestamp('2017-07-24 06:58:00.913000'),
#   'latitude': '64.1333333',
#   'longitude': '-141.5333334',
#   'maintext': 'This fire was a False Alarm.',
#   'prev_acreage': 0.1,
#   'prev_text': ''},
#  {'acreage': 905.6,
#   'cause': 'Lightning',
#   'designation': 'Big Waldren Fork',
#   'discoverydatetime': Timestamp('2017-07-14 19:08:27.172000'),
#   'lastupdatedatetime': Timestamp('2017-07-24 04:00:08.172000'),
#   'latitude': '62.529034',
#   'longitude': '-156.533152',
#   'maintext': 'The fire was flown by H-212HL.  Personnel reported the fire was burning rank 3 in continuous hardwoods and tundra, 20% active, torching and smoldering with 40` flame lengths.  The fire had increased in size by 250 acres.  There were no resources threatened and the fire remains in monitor status.',
#   'prev_acreage': 900.0,
#   'prev_text': 'The fire was flown by H-212HL.  Personnel reported the fire was burning rank 3 in continuous hardwoods and tundra, 20% active, torching and smoldering with 40` flame lengths.  The fire had increased in size by 250 acres.  There were no resources threatened and the fire remains in monitor status.'},
#  {'acreage': 0.4,
#   'cause': 'Human',
#   'designation': '0.5 Mile Murphy Dome Road',
#   'discoverydatetime': Timestamp('2017-07-23 15:11:54.249000'),
#   'lastupdatedatetime': Timestamp('2017-07-23 22:43:34.249000'),
#   'latitude': '64.916422',
#   'longitude': '-147.94623',
#   'maintext': 'At 1511, two DOF engines and Chena Goldstream Fire and Rescue responded to a structure fire with wildland involvement on Murphy Dome Road. The structure was fully involved upon arrival and the wildland fire was approximately 0.25 acre in size and burning in black spruce with 1-4 foot flame lengths. The fire was located in a Critical suppression management area and a structure adjacent to the fire was threatened. DOF Helicopter H120SH responded and conducted bucket work over the fire. The fire was contained at 0.4 acres. During the next operational shift, DOF personnel will return to the fire to continue mop up.',
#   'prev_acreage': 0.4,
#   'prev_text': ''},
#  {'acreage': 0.2,
#   'cause': 'Lightning',
#   'designation': 'Lower Birch',
#   'discoverydatetime': Timestamp('2017-07-21 17:51:49.281000'),
#   'lastupdatedatetime': Timestamp('2017-07-23 21:04:00.281000'),
#   'latitude': '66.4308055',
#   'longitude': '-146.8511111',
#   'maintext': 'Personnel mopped up the fire throughout the shift, minimal heat was found. All resources will be demobilized tomorrow (7/24).',
#   'prev_acreage': 0.2,
#   'prev_text': 'Personnel worked to secure the fire line and clean up downed trees. Progress continues through the mop up phase. Tentative demobilization on Monday (7/24).'},
#  {'acreage': 11.8,
#   'cause': 'Lightning',
#   'designation': 'Jack White',
#   'discoverydatetime': Timestamp('2017-07-16 18:14:24.172000'),
#   'lastupdatedatetime': Timestamp('2017-07-22 21:25:00.172000'),
#   'latitude': '66.965',
#   'longitude': '-151.28',
#   'maintext': 'Zone aircraft N309VS flew the fire area and observed no smoke or change in size. Resources performed a final grid of the fire and found no heat.  Helicopter N405AE was utilized to transport excess supplies to Bettles to prepare for demobilization.  All resources will demobilize from the incident tomorrow (7/23).',
#   'prev_acreage': 11.8,
#   'prev_text': 'Zone aircraft N309VS flew the fire area annd observed no smoke or change in size. Resources performed a final grid of the fire and found no heat.  Helicopter N405AE was utilized to transport excess supplies to Bettles to prepare for demobilization.  All resources will demobilize from the incident tomorrow (7/23).'},
#  {'acreage': 10.0,
#   'cause': 'Lightning',
#   'designation': 'Sulatna River',
#   'discoverydatetime': Timestamp('2017-07-21 15:00:28.188000'),
#   'lastupdatedatetime': Timestamp('2017-07-22 21:12:00.188000'),
#   'latitude': '64.59',
#   'longitude': '-154.53',
#   'maintext': 'Zone surveillance aircraft N309VS flew over the area and could not locate any smoke or remnants of a fire. The Tanana Zone will continue to monitor the area with aerial resources.',
#   'prev_acreage': 10.0,
#   'prev_text': 'Fire was initially reported by a private pilot to Flight Services. The fire was estimated at 7-10 acres in size. Galena Zone helicopter 32AT did a flyby of the coordinates and was unable to locate a fire. Zone aircraft N309VS flew the area at 19:30 and was unable to locate the fire. The Tanana Zone will continue to monitor the area with aerial resources.'},
#  {'acreage': 47.6,
#   'cause': 'Lightning',
#   'designation': 'Alatna Hills',
#   'discoverydatetime': Timestamp('2017-07-15 17:33:23.128000'),
#   'lastupdatedatetime': Timestamp('2017-07-22 13:39:00.128000'),
#   'latitude': '67.0286667',
#   'longitude': '-152.1536667',
#   'maintext': 'The fire was flown by zone surveillance aircraft N309VS. Personnel on board reported no smokes or change in size.',
#   'prev_acreage': 47.6,
#   'prev_text': 'At 15:24 the fire was flown by zone surveillance aircraft N190PE. The fire had no active perimeter and no smokes were visible.'},
#  {'acreage': 98.4,
#   'cause': 'Lightning',
#   'designation': 'Chalatna Creek',
#   'discoverydatetime': Timestamp('2017-07-16 21:15:57.281000'),
#   'lastupdatedatetime': Timestamp('2017-07-22 12:58:00.281000'),
#   'latitude': '66.484',
#   'longitude': '-151.1151667',
#   'maintext': 'Fire was flown by zone aircraft N309VS and no smoke or changes were observed.',
#   'prev_acreage': 98.4,
#   'prev_text': 'Zone surveillance aircraft N190PE flew the fire and reported no smokes visible.'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'MPMG 19',
#   'discoverydatetime': Timestamp('2017-07-21 16:15:09.649000'),
#   'lastupdatedatetime': Timestamp('2017-07-21 16:20:00.649000'),
#   'latitude': '64.8023333',
#   'longitude': '-147.6473333',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 3.0,
#   'cause': 'Lightning',
#   'designation': 'Owens',
#   'discoverydatetime': Timestamp('2017-07-20 18:30:17.810000'),
#   'lastupdatedatetime': Timestamp('2017-07-20 21:46:00.810000'),
#   'latitude': '67.6232778',
#   'longitude': '-143.2066944',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': '33 Mile Loop',
#   'discoverydatetime': Timestamp('2017-07-19 17:02:02.266000'),
#   'lastupdatedatetime': Timestamp('2017-07-20 08:15:00.266000'),
#   'latitude': '63.9553889',
#   'longitude': '-145.5297222',
#   'maintext': 'A dozer contracted by the military caught fire in the Donnelly Training Area along the 33 Mile Loop road. Range control personnel responded and were able to suppress the fire before it advanced further  into the wildland. Additional resources from Delta responded but were not needed as range control reported they had contained the fire. Range personnel will check the site tomorrow (7/19).',
#   'prev_acreage': 0.1,
#   'prev_text': 'A dozer contracted by the military caught fire in the Donnelly Training Area along the 33 Mile Loop road. Range control personnel responded and were able to suppress the fire before it advanced to the wildland. Additional resources from Delta responded but were not needed as range control reported they had contained the fire. Range personnel will check the site tomorrow (7/19).'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'McCoy Creek',
#   'discoverydatetime': Timestamp('2017-07-18 13:46:53.348000'),
#   'lastupdatedatetime': Timestamp('2017-07-20 06:36:00.348000'),
#   'latitude': '64.49',
#   'longitude': '-146.356667',
#   'maintext': 'Received a report of a small fire smoldering just east of the pipeline.  H120SH flew the fire and dropped off the helitack load to begin suppression operations.  Fire was a 10 x 10 spot, rank 1 in black spruce 100 percent active.  Fire was extinguished and they began to green grid and cold trail the area.  3 Forestry personnel will remain overnight to ensure no further heats pop up and prepare for demobilization on Thursday.',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'SARKAR RIVER BRIDGE',
#   'discoverydatetime': Timestamp('2017-07-18 11:43:00.679000'),
#   'lastupdatedatetime': Timestamp('2017-07-19 06:37:00.679000'),
#   'latitude': '55.9508333',
#   'longitude': '-133.2344444',
#   'maintext': 'Fire was called in by local citizen 7/18/17 at 0822.  Forest Service personnel responded and worked the fire and called it contained and in monitor status at 1400.  Will recheck tomorrow or next day.  All resources have been released.',
#   'prev_acreage': 0.0,
#   'prev_text': ''},
#  {'acreage': 5.0,
#   'cause': 'Lightning',
#   'designation': 'Essie Creek',
#   'discoverydatetime': Timestamp('2017-07-18 15:09:56.679000'),
#   'lastupdatedatetime': Timestamp('2017-07-19 06:19:00.679000'),
#   'latitude': '64.9743333',
#   'longitude': '-143.075',
#   'maintext': 'The fire was discovered by Zone aircraft N9011N. The fire is 5 acres with a 0% active perimeter and one interior smoke smoldering on the north side in a mix of white and black spruce. The fire plots in Limited and is placed in monitor status.',
#   'prev_acreage': 5.0,
#   'prev_text': 'The fire was discovered by Zone aircraft N9011N. The fire is 5 acres with a 0% active perimeter and one interior smoke smoldering on the North side in a mix of white and black spruce. The fire plots in limited and is placed in monitor status.'},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Hidden Rain',
#   'discoverydatetime': Timestamp('2017-07-18 18:00:21.809000'),
#   'lastupdatedatetime': Timestamp('2017-07-18 20:37:02.809000'),
#   'latitude': '60.468567',
#   'longitude': '-150.2029',
#   'maintext': 'DOF engine responded to a reported abandoned campfire near Hidden Lake. Upon arrival found a smoldering, rank 1, 5` x 5` fire that was burning in leaf litter and roots.  Engine personnel took suppression action and the fire was contained, controlled, and placed in monitor status.',
#   'prev_acreage': 0.1,
#   'prev_text': ''},
#  {'acreage': 3.0,
#   'cause': '',
#   'designation': 'Paddle Creek 2',
#   'discoverydatetime': Timestamp('2017-07-18 17:45:06.108000'),
#   'lastupdatedatetime': Timestamp('2017-07-18 17:55:00.108000'),
#   'latitude': '65.9113333',
#   'longitude': '-143.2696667',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 3.6,
#   'cause': 'Lightning',
#   'designation': 'John River',
#   'discoverydatetime': Timestamp('2017-07-14 13:51:48.163000'),
#   'lastupdatedatetime': Timestamp('2017-07-17 13:02:00.163000'),
#   'latitude': '66.9699166',
#   'longitude': '-151.6166111',
#   'maintext': 'Four smokejumpers were demobilized from this incident and reassigned to fire 344.',
#   'prev_acreage': 3.6,
#   'prev_text': 'After performing a check of the fire in the morning hours, an area of heat was discovered.  The demobilization plan was adjusted to a later date to allow for full suppression of the newly discovered heat. Plans for tomorrow include the demobilization of the all 4 smokejumpers.'},
#  {'acreage': 22.0,
#   'cause': 'Lightning',
#   'designation': 'Montana Creek',
#   'discoverydatetime': Timestamp('2017-07-14 19:03:52.758000'),
#   'lastupdatedatetime': Timestamp('2017-07-15 21:16:11.758000'),
#   'latitude': '62.5425',
#   'longitude': '-157.453333',
#   'maintext': 'Fire personnel worked the fire through most the evening, and continued throughout the day. The fire was under 100 percent cloud cover, but never received any precipitation by evening time of 7/15. Tentative demob is planned for tomorrow, 7/16,  around mid afternoon. Acreage change due to gps mapping.',
#   'prev_acreage': 18.0,
#   'prev_text': 'The fire was found by multiple modis spots. BD-840 was launched from Palmer, and sized the fire up as 15 acres, 60 percent active, burning in grass and brush. J-07 responded, deploying 8 jumpers and sizing the fire up as 18 acres and 30 percent active. Personnel will take advantage of the high evening humidity, working late into the evening to help make significant progress towards their full suppression goals.'},
#  {'acreage': 0.0,
#   'cause': 'Lightning',
#   'designation': 'George Lake Hills',
#   'discoverydatetime': Timestamp('2017-07-13 08:10:24.348000'),
#   'lastupdatedatetime': Timestamp('2017-07-13 15:57:52.348000'),
#   'latitude': '63.75',
#   'longitude': '-144.316667',
#   'maintext': 'A small column of smoke was reported to the duty officer around 22:30 on 7/12 by a resident on Sand Lake.  Helitack responded after the fog and mist lifted on 7/13.  The reporter could no longer see any smoke once helitack was launched.  Helicopter 873HL thoroughly scanned the area and did not find any blackened ground or smoke.  It is planned to search the area on 7/14 when the weather is forecasted to be warmer and clearer.',
#   'prev_acreage': 0.0,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Salchaket Subdivision',
#   'discoverydatetime': Timestamp('2017-06-21 12:21:15.934000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '64.39848',
#   'longitude': '-146.777772',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 5.0,
#   'cause': 'Lightning',
#   'designation': 'North Ladue River',
#   'discoverydatetime': Timestamp('2017-06-23 16:19:45.177000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '63.525883',
#   'longitude': '-140.87755',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Crooked Creek',
#   'discoverydatetime': Timestamp('2017-06-27 11:36:43.341000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '61.870333',
#   'longitude': '-158.105167',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Boulder Creek',
#   'discoverydatetime': Timestamp('2017-06-29 12:21:44.502000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '64.9',
#   'longitude': '-144.95',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Parks Pullout',
#   'discoverydatetime': Timestamp('2017-07-02 19:50:34.397000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '64.757317',
#   'longitude': '-148.3757',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Lac Viex',
#   'discoverydatetime': Timestamp('2017-07-04 11:27:19.262000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '61.516047',
#   'longitude': '-150.042347',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'Hog Heaven',
#   'discoverydatetime': Timestamp('2017-07-05 11:02:33.983000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '61.925617',
#   'longitude': '-145.428167',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''},
#  {'acreage': 0.1,
#   'cause': 'Human',
#   'designation': 'False Alarm _11',
#   'discoverydatetime': Timestamp('2017-07-07 11:16:44.853000'),
#   'lastupdatedatetime': NaT,
#   'latitude': '65.200167',
#   'longitude': '-148.054317',
#   'maintext': '',
#   'prev_acreage': nan,
#   'prev_text': ''}]

# %%
import math
def sqkm(acres, perc):
    return math.sqrt(acres/2.5/100) * perc * 3.14 * 2 * 0.02

# %%
sqkm(2661, .8)
# Out:
# 0.32781744367498206
